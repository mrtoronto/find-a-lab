# %% [markdown]
# # PubMed PhD Supervisor Search

# %% [markdown]
# ## Load Packages

# %%
import re
import ast
import pandas as pd
from functions import get_article_ids
from collections import Counter
from tqdm.notebook import tqdm
from geotext import GeoText

# %%
def get_locations(affiliations):
    locations = []
    for affiliation in affiliations:
        places = GeoText(affiliation)
        if places:
            response = list(set(list(places.countries) + list(places.cities)))
            locations = locations + response
        else:
            pass
        if 'University' in locations: locations.remove('University')
        return locations
    
def get_location(affiliation):
    locations = []
    #for affiliation in affiliations:
    places = GeoText(affiliation)
    if places:
        city_str = ' '.join(set([city for city in places.cities if city != 'University'])).strip()
        locations = f"{city_str}, {places.countries[0]}"
        #locations = locations + response
    else:
        pass
    return locations

# %%
get_location('Department of Psychiatry, University of Toronto, Toronto, ON, Canada.')
# Out:
# 'Toronto, Canada'

# %% [markdown]
# ## Set Variables

# %%
query = 'Herscot Center'
loi = ['united states', 'france', 'netherlands', 'denmark', 'sweden', 'germany', 'switzerland', 'norway', 
                   'finland', 'luxembourg', 'belgium', 'austria', 'cambridge', 'oxford', 'london']

# %% [markdown]
# ## Fetch Entries from PubMed

# %%
response = get_article_ids(query, sort = 'relevance', from_year = 2010, api_key="9f66a38099f29d882365afb5ea170b1ef608")
papers_result = response[0].to_dict('records')
affiliations_result = response[1]
# Out:
# Query:Herscot Center
# Number of Results: 22
# HBox(children=(FloatProgress(value=0.0, description='Downloading Herscot Center data in chunks : ', max=1.0, s…

# %%
papers_result
# Out:
# [{'title': 'Juvenile cataract in association with tuberous sclerosis complex.',
#   'pmid': '32340510',
#   'keywords': ['Tuberous sclerosis complex', 'cataract', 'juvenile'],
#   'pub_type_list': ['Journal Article'],
#   'journal_info_list': ['Ophthalmic genetics',
#    '1744-5094',
#    'Electronic',
#    'Ophthalmic Genet.'],
#   'author_list': [['A L', 'AL', 'Geffrey'],
#    ['K R', 'KR', 'Geenen'],
#    ['E', 'E', 'Abati'],
#    ['S H', 'SH', 'Greenstein'],
#    ['D K', 'DK', 'VanderVeen'],
#    ['R L', 'RL', 'Levy'],
#    ['S L', 'SL', 'Davidson'],
#    ['M P', 'MP', 'McGarrey'],
#    ['E A', 'EA', 'Thiele'],
#    ['M E', 'ME', 'Aronow']],
#   'affil_list': ['Massachusetts Eye and Ear, Harvard Medical School, Boston, Massachusetts, USA.'],
#   'pubdate': '2020',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32340510',
#   'abstract': [None]},
#  {'title': 'A telehealth approach to improving clinical trial access for infants with tuberous sclerosis complex.',
#   'pmid': '31969108',
#   'keywords': ['Autism spectrum disorder',
#    'Behavioral intervention',
#    'Clinical trial recruitment',
#    'Early intervention',
#    'Remote delivery',
#    'Telehealth',
#    'Tuberous sclerosis complex'],
#   'pub_type_list': ['Journal Article'],
#   'journal_info_list': ['Journal of neurodevelopmental disorders',
#    '1866-1955',
#    'Electronic',
#    'J Neurodev Disord'],
#   'author_list': [['Carly', 'C', 'Hyde'],
#    ['Maria', 'M', 'Pizzano'],
#    ['Nicole M', 'NM', 'McDonald'],
#    ['Charles A', 'CA', 'Nelson'],
#    ['Connie', 'C', 'Kasari'],
#    ['Elizabeth A', 'EA', 'Thiele'],
#    ['Shafali S', 'SS', 'Jeste']],
#   'affil_list': ['UCLA Semel Institute, Los Angeles, CA, 90095, USA.'],
#   'pubdate': '2020',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31969108',
#   'abstract': ['Research in rare genetic syndromes associated with ASD is often hampered by the wide geographic distribution of families and the presence of medical comorbidities, such as epilepsy, that may preclude travel to clinical sites. These challenges can limit the sample size and generalizability of the cohorts included in both natural history studies and clinical trials. Tuberous sclerosis complex (TSC) is a rare genetic syndrome that confers an elevated risk for autism spectrum disorder (ASD), with social communication delays identified in this population as early as 12\u2009months of age. Early identification of risk necessitates parallel testing of early intervention, prompting the first randomized controlled clinical trial of behavioral intervention for infants with TSC (NCT03422367). However, considerable early recruitment challenges have mandated the systematic identification of enrollment barriers followed by modification of the study design to address these barriers.',
#    'Caregivers were interviewed regarding barriers to enrollment (phase 1). Adaptations to the intervention were made to address these barriers (phase 2). Outcomes based on this modification to the study design were defined by enrollment rate and participant demographics.',
#    'Qualitative reports from caregivers indicated that distance and time were the primary barriers to clinical trial enrollment. The intervention was then modified to a remote model, with at-home, parent-delivered intervention, and weekly video conferencing with interventionists at the study sites. Enrollment increased 10-fold (from 3 to 30 participants) within 1\u2009year and included a more diverse and clinically representative cohort of infants.',
#    'The design and implementation of more scalable methods to disseminate research remotely can substantially improve access to clinical trials in rare neurodevelopmental disorders. The lessons learned from this trial can serve as a model for future studies not only in rare conditions, but in other populations that lack adequate access, such as families with limited financial or clinical resources. Continued efforts will further refine delivery methods to enhance efficiency and ease of these delivery systems for families.']},
#  {'title': 'Perception of impact of Dravet syndrome on children and caregivers in multiple countries: looking beyond seizures.',
#   'pmid': '30828793',
#   'keywords': [],
#   'pub_type_list': ['Journal Article'],
#   'journal_info_list': ['Developmental medicine and child neurology',
#    '1469-8749',
#    'Electronic',
#    'Dev Med Child Neurol'],
#   'author_list': [['Rima', 'R', 'Nabbout'],
#    ['Stephane', 'S', 'Auvin'],
#    ['Catherine', 'C', 'Chiron'],
#    ['Elizabeth', 'E', 'Thiele'],
#    ['Helen', 'H', 'Cross'],
#    ['Ingrid E', 'IE', 'Scheffer'],
#    ['Amy L', 'AL', 'Schneider'],
#    ['Renzo', 'R', 'Guerrini'],
#    ['Nicola', 'N', 'Williamson'],
#    'Zogenix and Adelphi Values study group'],
#   'affil_list': ['PCO, Adelphi Values Ltd, Bollington, UK.'],
#   'pubdate': '2019',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30828793',
#   'abstract': ['To assess the relevance and generalizability across countries of concepts of the impact of Dravet syndrome beyond seizures, as recognized by families.',
#    'Caregivers of children with Dravet syndrome in four countries (Australia [n=8]; USA, UK, and Italy [all n=4]) participated in 1-hour qualitative telephone interviews, identifying key Dravet syndrome concepts. Interviews were recorded, transcribed, and, where necessary, translated into English for thematic analysis. Conceptual saturation was assessed and findings compared to the previously developed French conceptual disease model.',
#    'The most common seizure types reported by caregivers were tonic-clonic, absence, or focal-impaired awareness (localized/partial). Fever and physical activity were the most commonly reported triggers. Patient-relevant impacts included impairment in cognition, motor skills, communication, social skills, and behavioural functioning. Caregivers consistently reported negative social, physical, and family impacts. Concepts identified in the interviews showed similarity with the French conceptual model. Minor differences between countries are likely to reflect variations in health care systems.',
#    'Findings in Italy, Australia, UK, and USA confirm that the key impacts of Dravet syndrome on children and caregivers identified in France are generalizable across countries. Key symptom and impact concepts relevant to children and parents should be targeted as critical outcomes in new therapy evaluations.',
#    'Relevance of the impact of Dravet syndrome on children and caregivers was confirmed across countries. Patient and caregiver-relevant Dravet syndrome impacts contribute to poorer health-related quality of life. Indirect seizure impacts were reported to be as important as direct impacts. Country-specific differences in concepts probably reflect differences in health care systems.']},
#  {'title': 'Outcome of childhood-onset epilepsy from adolescence to adulthood: Transition issues.',
#   'pmid': '28256379',
#   'keywords': ['Adolescence', 'Epilepsy', 'Outcome', 'Transition'],
#   'pub_type_list': ['Journal Article', 'Review'],
#   'journal_info_list': ['Epilepsy & behavior : E&B',
#    '1525-5069',
#    'Electronic',
#    'Epilepsy Behav'],
#   'author_list': [['R', 'R', 'Nabbout'],
#    ['D M', 'DM', 'Andrade'],
#    ['N', 'N', 'Bahi-Buisson'],
#    ['H', 'H', 'Cross'],
#    ['I', 'I', 'Desquerre'],
#    ['O', 'O', 'Dulac'],
#    ['T', 'T', 'Granata'],
#    ['E', 'E', 'Hirsch'],
#    ['V', 'V', 'Navarro'],
#    ['L', 'L', 'Ouss'],
#    ['P L', 'PL', 'Pearl'],
#    ['D', 'D', 'Schmidt'],
#    ['E', 'E', 'Thiele'],
#    ['P R', 'PR', 'Camfield'],
#    ['C S', 'CS', 'Camfield']],
#   'affil_list': ['Dalhousie University, IWK Health Centre, Halifax, Nova Scotia, Canada.'],
#   'pubdate': '2017',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28256379',
#   'abstract': ["This is the second of three papers that summarize the second symposium on Transition in Epilepsies held in Paris in June 2016. This paper addresses the outcome for some particularly challenging childhood-onset epileptic disorders with the goal of recommending the best approach to transition. We have grouped these disorders in five categories with a few examples for each. The first group includes disorders presenting in childhood that may have late- or adult-onset epilepsy (metabolic and mitochondrial disorders). The second group includes disorders with changing problems in adulthood (tuberous sclerosis complex, Rett syndrome, Dravet syndrome, and autism). A third group includes epilepsies that change with age (Childhood Absence Epilepsy, Juvenile Myoclonic Epilepsy, West Syndrome, and Lennox-Gastaut syndrome). A fourth group consists of epilepsies that vary in symptoms and severity depending on the age of onset (autoimmune encephalitis, Rasmussen's syndrome). A fifth group has epilepsy from structural causes that are less likely to evolve in adulthood. Finally we have included a discussion about the risk of later adulthood cerebrovascular disease and dementia following childhood-onset epilepsy. A detailed knowledge of each of these disorders should assist the process of transition to be certain that attention is paid to the most important age-related symptoms and concerns."]},
#  {'title': 'Rib and vertebral bone fibrous dysplasia in a child with tuberous sclerosis complex.',
#   'pmid': '26177838',
#   'keywords': ['bone lesion',
#    'fibrous dysplasia',
#    'mTOR inhibitors',
#    'pediatric',
#    'tuberous sclerosis complex'],
#   'pub_type_list': ['Case Reports',
#    'Journal Article',
#    "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['American journal of medical genetics. Part A',
#    '1552-4833',
#    'Electronic',
#    'Am. J. Med. Genet. A'],
#   'author_list': [['Patrick', 'P', 'Li'],
#    ['Susana', 'S', 'Boronat'],
#    ['Alexandra Lauryn', 'AL', 'Geffrey'],
#    ['Ignasi', 'I', 'Barber'],
#    ['Brian Edward', 'BE', 'Grottkau'],
#    ['Elizabeth Anne', 'EA', 'Thiele']],
#   'affil_list': ['Herscot Center for Tuberous Sclerosis Complex, Massachusetts General Hospital, Boston, Massachusetts.'],
#   'pubdate': '2015',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/26177838',
#   'abstract': ['Tuberous sclerosis complex (TSC) is an autosomal dominant genetic disorder characterized by benign hamartomas in multiple organ systems, primarily the skin, brain, heart, kidneys, lungs, and eyes. The skeletal system is commonly affected in patients with TSC, but these bone lesions are generally asymptomatic and have not been well characterized. We present clinically significant bone growth in two ribs and vertebrae in an 8-year-old male patient with TSC and discuss the effects of mammalian target of rapamycin (mTOR) inhibitors as a possible treatment for these osseous abnormalities. This report suggests that skeletal lesions may hold more clinical significance than previously assumed and that further research should be directed toward understanding bone involvement in TSC.']},
#  {'title': 'Primary intestinal lymphangiectasia treated with rapamycin in a child with tuberous sclerosis complex (TSC).',
#   'pmid': '25943403',
#   'keywords': ['mTOR',
#    'primary intestinal lymphangiectasia (PIL)',
#    'rapamycin',
#    'tuberous sclerosis complex (TSC)'],
#   'pub_type_list': ['Case Reports',
#    'Journal Article',
#    "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['American journal of medical genetics. Part A',
#    '1552-4833',
#    'Electronic',
#    'Am. J. Med. Genet. A'],
#   'author_list': [['Sarah F', 'SF', 'Pollack'],
#    ['Alexandra L', 'AL', 'Geffrey'],
#    ['Elizabeth A', 'EA', 'Thiele'],
#    ['Uzma', 'U', 'Shah']],
#   'affil_list': ['Department of Pediatric Gastroenterology, Hepatology and Nutrition, Massachusetts General Hospital, Boston, Massachusetts.'],
#   'pubdate': '2015',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/25943403',
#   'abstract': ['Primary intestinal lymphangiectasia (PIL) is a rare protein-losing enteropathy characterized by a congenital malformation of the lymphatic vessels of the small intestine causing insufficient drainage and leakage of lymph fluid. Tuberous sclerosis complex (TSC) is an autosomal dominant genetic disorder characterized by benign hamartomas in multiple organ systems. While the lymphatic system has been implicated in TSC through lymphangioleiomyomatosis (LAM) and lymphedema, this paper reports the first case of PIL in TSC, a female patient with a TSC2 mutation. She developed persistent and significant abdominal distension with chronic diarrhea during her first year of life. Due to lack of treatment options and the involvement of the mTOR pathway in TSC, a trial of an mTOR inhibitor, rapamycin, was initiated. This treatment was highly effective, with improvement in clinical symptoms of PIL as well as abnormal laboratory values including VEGF-C, which was elevated to over seven times the normal upper limit before treatment. This case suggests that PIL is a rare manifestation of TSC, warranting the use of mTOR inhibitors in future studies.']},
#  {'title': 'Lacosamide use in the treatment of refractory epilepsy in tuberous sclerosis complex.',
#   'pmid': '25847341',
#   'keywords': ['Adjunctive therapy',
#    'Anticonvulsants',
#    'Epilepsy',
#    'LCS',
#    'Tuberous sclerosis complex'],
#   'pub_type_list': ['Journal Article', "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Epilepsy research',
#    '1872-6844',
#    'Electronic',
#    'Epilepsy Res.'],
#   'author_list': [['Alexandra L', 'AL', 'Geffrey'],
#    ['Olivia D', 'OD', 'Belt'],
#    ['Jan L', 'JL', 'Paolini'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': ['Herscot Center for Tuberous Sclerosis Complex, Massachusetts General Hospital, 175 Cambridge Street, Suite 340, Boston, MA 02114, United States. Electronic address: ethiele@partners.org.'],
#   'pubdate': '2015',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/25847341',
#   'abstract': ['Lacosamide (LCS) was approved by the United States Food and Drug Administration (FDA) in 2008 as adjunctive therapy to other anti-epileptic drugs (AEDs) to treat focal-onset seizures, with or without secondary generalization. Its role in the treatment of epilepsy in individuals with tuberous sclerosis complex (TSC) has yet to be determined. This study evaluates LCS treatment of focal-onset refractory epilepsy in patients with TSC. From November 2009 to June 2014, 46 TSC patients followed by a single neurologist were treated with LCS. Forty-eight percent were responders (seizure reduction ≥50%). No significant differences between responders and non-responders in demographic characteristics were found. LCS appears to be an effective and safe treatment of refractory focal onset seizures in TSC. Determining the long-term tolerability and efficacy of LCS in TSC patients requires additional clinical experience. ']},
#  {'title': 'Renal cell carcinoma in tuberous sclerosis complex.',
#   'pmid': '24832166',
#   'keywords': [],
#   'pub_type_list': ['Journal Article',
#    'Multicenter Study',
#    'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['The American journal of surgical pathology',
#    '1532-0979',
#    'Electronic',
#    'Am. J. Surg. Pathol.'],
#   'author_list': [['Ping', 'P', 'Yang'],
#    ['Kristine M', 'KM', 'Cornejo'],
#    ['Peter M', 'PM', 'Sadow'],
#    ['Liang', 'L', 'Cheng'],
#    ['Mingsheng', 'M', 'Wang'],
#    ['Yu', 'Y', 'Xiao'],
#    ['Zhong', 'Z', 'Jiang'],
#    ['Esther', 'E', 'Oliva'],
#    ['Sergiusz', 'S', 'Jozwiak'],
#    ['Robert L', 'RL', 'Nussbaum'],
#    ['Adam S', 'AS', 'Feldman'],
#    ['Elahna', 'E', 'Paul'],
#    ['Elizabeth A', 'EA', 'Thiele'],
#    ['Jane J', 'JJ', 'Yu'],
#    ['Elizabeth P', 'EP', 'Henske'],
#    ['David J', 'DJ', 'Kwiatkowski'],
#    ['Robert H', 'RH', 'Young'],
#    ['Chin-Lee', 'CL', 'Wu']],
#   'affil_list': [],
#   'pubdate': '2014',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/24832166',
#   'abstract': ['Renal cell carcinoma (RCC) occurs in 2% to 4% of patients with tuberous sclerosis complex (TSC). Previous reports have noted a variety of histologic appearances in these cancers, but the full spectrum of morphologic and molecular features has not been fully elucidated. We encountered 46 renal epithelial neoplasms from 19 TSC patients and analyzed their clinical, pathologic, and molecular features, enabling separation of these 46 tumors into 3 groups. The largest subset of tumors (n=24) had a distinct morphologic, immunologic, and molecular profile, including prominent papillary architecture and uniformly deficient succinate dehydrogenase subunit B (SDHB) expression prompting the novel term "TSC-associated papillary RCC (PRCC)." The second group (n=15) were morphologically similar to a hybrid oncocytic/chromophobe tumor (HOCT), whereas the last 7 renal epithelial neoplasms of group 3 remained unclassifiable. The TSC-associated PRCCs had prominent papillary architecture lined by clear cells with delicate eosinophilic cytoplasmic thread-like strands that occasionally appeared more prominent and aggregated to form eosinophilic globules. All 24 (100%) of these tumors were International Society of Urological Pathology (ISUP) nucleolar grade 2 or 3 with mostly basally located nuclei. Tumor cells from 17 of 24 TSC-associated PRCCs showed strong, diffuse labeling for carbonic anhydrase IX (100%), CK7 (94%), vimentin (88%), and CD10 (83%) and were uniformly negative for SDHB, TFE3, and AMACR. Gains of chromosomes 7 and 17 were found in 2 tumors, whereas chromosome 3p deletion and TFE3 translocations were not detected. In this study, we reported a sizable cohort of renal tumors seen in TSC and were able to identify them as different morphotypes, which may help to expand the morphologic spectrum of TSC-associated RCC.']},
#  {'title': 'Lymphedema in tuberous sclerosis complex.',
#   'pmid': '24668795',
#   'keywords': ['edema',
#    'lymphatic abnormalities',
#    'lymphedema',
#    'tuberous sclerosis complex'],
#   'pub_type_list': ['Journal Article', 'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['American journal of medical genetics. Part A',
#    '1552-4833',
#    'Electronic',
#    'Am. J. Med. Genet. A'],
#   'author_list': [['Alexandra L', 'AL', 'Geffrey'],
#    ['Julianna E', 'JE', 'Shinnick'],
#    ['Brigid A', 'BA', 'Staley'],
#    ['Susana', 'S', 'Boronat'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2014',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/24668795',
#   'abstract': ['Congenital lymphedema has been described as a possible rare association of tuberous sclerosis complex (TSC), with only six previous cases reported in the literature. TSC is an autosomal dominant, multisystem disorder connected to aberrant regulation of the mammalian target of rapamycin (mTOR) pathway. The aim of this study is to review cases of lymphedema in a large cohort of TSC patients. The medical records of 268 patients seen at The Herscot Center for Children and Adults with Tuberous Sclerosis Complex at the Massachusetts General Hospital from 2002 to 2012 were retrospectively reviewed for reports of lymphedema or edema of unknown etiology. Genotypic and phenotypic data were collected in accordance with institutional review board (IRB) approval. This cohort presents two new cases of congenital lymphedema in TSC patients and acquired lymphedema was found in eight additional cases. Thus, we report 10 new cases of lymphedema in TSC (4%). The two patients with congenital lymphedema were female, as were the previous six reported cases. The frequency of lymphedema reported here (4%) is higher than the estimated prevalence in the general population (0.133-0.144%), suggesting a higher frequency of lymphedema in TSC. This study shows that patients with TSC and lymphedema are more likely to be females with renal AMLs and suggests that congenital lymphedema is a gender-specific (female) manifestation of TSC. Exploration of the potential role of mTOR antagonists may be important in treatment of lymphedema in TSC patients.']},
#  {'title': 'Tuberous sclerosis complex without tubers and subependymal nodules: a phenotype-genotype study.',
#   'pmid': '23909698',
#   'keywords': ['mosaicism',
#    'neural crest',
#    'no mutation identified (NMI)',
#    'tuberous sclerosis complex (TSC)'],
#   'pub_type_list': ['Journal Article', "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Clinical genetics',
#    '1399-0004',
#    'Electronic',
#    'Clin. Genet.'],
#   'author_list': [['S', 'S', 'Boronat'],
#    ['E A', 'EA', 'Shaaya'],
#    ['C M', 'CM', 'Doherty'],
#    ['P', 'P', 'Caruso'],
#    ['E A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2013',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/23909698',
#   'abstract': ['Tuberous sclerosis complex (TSC) is caused by a mutation in the TSC1 or TSC2 genes. However, 15% of patients have no mutation identified. Tubers and subependymal nodules (SENs) are the typical brain lesions in TSC and are present in 90-95% of patients. The objective of this study is to characterize the specific genotype-phenotype of patients without these lesions. We analyzed the features of 11 patients without typical TSC neuroanatomic features. Ten had TSC1/TSC2 mutational analysis, which was negative. Clinically they had lesions thought to be of neural crest (NC) origin, such as hypomelanotic macules, facial angiofibromas, cardiac rhabdomyomas, angiomyolipomas, and lymphangioleiomyomatosis. We hypothesize that patients without tubers and SENs reflect mosaicism caused by a mutation in TSC1 or TSC2 in a NC cell during embryonic development. This may explain the negative results in TSC1 and TSC2 testing in DNA from peripheral leukocytes. ']},
#  {'title': 'The neuroanatomical phenotype of tuberous sclerosis complex: focus on radial migration lines.',
#   'pmid': '23644537',
#   'keywords': [],
#   'pub_type_list': ['Journal Article',
#    'Research Support, N.I.H., Extramural',
#    "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Neuroradiology',
#    '1432-1920',
#    'Electronic',
#    'Neuroradiology'],
#   'author_list': [['Agnies M', 'AM', 'van Eeghen'],
#    ['Laura Ortiz', 'LO', 'Terán'],
#    ['Jason', 'J', 'Johnson'],
#    ['Margaret B', 'MB', 'Pulsifer'],
#    ['Elizabeth A', 'EA', 'Thiele'],
#    ['Paul', 'P', 'Caruso']],
#   'affil_list': ['Department of Radiology, Massachusetts General Hospital, Boston, MA, USA.'],
#   'pubdate': '2013',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/23644537',
#   'abstract': ['The contribution of radial migration lines (RMLs) to the neuroanatomical and neurocognitive phenotype of tuberous sclerosis complex (TSC) is unclear. The aim of this study was to perform a comprehensive evaluation of the neuroradiological phenotype of TSC, distinguishing RMLs from normal-appearing white matter (NAWM) using diffusion tensor imaging (DTI) and volumetric fluid-attenuated inversion recovery imaging.',
#    'Magnetic resonance images of 30 patients with TSC were evaluated. The frequencies of RMLs, tubers, and subependymal nodules (SENs) were determined for every hemispheric lobe. Cerebellar lesions and subependymal giant cell tumors were counted. DTI metrics were obtained from the NAWM of every hemispheric lobe and from the largest RML and tuber. Analyses of variance and correlations were performed to investigate the associations between neuroanatomical characteristics and relationships between RML frequency and neurocognitive outcomes. NAWM DTI metrics were compared with measurements of 16 control patients.',
#    'A mean of 47 RMLs, 27 tubers, and 10 SENs were found per patient, and the frequencies of these lesions were strongly correlated (p < 0.001). RML fractional anisotropy and mean diffusivity were strongly inversely correlated (p = 0.003). NAWM DTI metrics were similar to the controls (p = 0.26). RML frequency was strongly associated with age of seizure onset (p = 0.003), intelligence outcomes (p = 0.01), and level of autistic features (p = 0.007).',
#    'A detailed neuroradiological phenotype is presented, showing that RMLs are the most frequent neuroanatomical lesion, are responsible for white matter DTI abnormalities, and are strongly associated with age of seizure onset, intelligence outcomes, and level of autistic features.']},
#  {'title': 'Cognitive outcome of surgery.',
#   'pmid': '23622227',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Review'],
#   'journal_info_list': ['Handbook of clinical neurology',
#    '0072-9752',
#    'Print',
#    'Handb Clin Neurol'],
#   'author_list': [['Anne', 'A', 'Gallagher'],
#    ['Isabelle', 'I', 'Jambaqué'],
#    ['Maryse', 'M', 'Lassonde']],
#   'affil_list': [],
#   'pubdate': '2013',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/23622227',
#   'abstract': ['Epilepsy surgery is now widely accepted as an effective therapeutic option for carefully selected children with medically refractory epilepsy. The surgical procedure may cause cognitive deficits or exacerbate existing impairments, but it may also improve cognitive abilities by the restoration of functions located in adjacent or contralateral areas that had been secondarily affected by the epilepsy or the underlying pathology. Compared to adults, better cognitive outcome has been reported in children, a finding probably due to the developing state of the brain, which possesses considerable structural and functional plasticity. More extensive and effective surgery such as hemispherectomy is more commonly used in the pediatric population, and this must also influence surgical outcome. However, studies related to cognitive outcome of epilepsy surgery in children are limited, and controversial results are often reported. In this chapter, we provide a current overview of the literature on cognitive outcomes in children who undergo different types of epilepsy surgery, including focal resections as well as corpus callosotomy and hemispherectomy. Early surgical intervention appears to be a rational option for the treatment of childhood epilepsy since many cognitive deficits are linked to the epileptic process and may disappear when seizures are controlled.']},
#  {'title': 'Understanding relationships between autism, intelligence, and epilepsy: a cross-disorder approach.',
#   'pmid': '23205844',
#   'keywords': [],
#   'pub_type_list': ['Journal Article',
#    'Research Support, N.I.H., Extramural',
#    "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Developmental medicine and child neurology',
#    '1469-8749',
#    'Electronic',
#    'Dev Med Child Neurol'],
#   'author_list': [['Agnies M', 'AM', 'van Eeghen'],
#    ['Margaret B', 'MB', 'Pulsifer'],
#    ['Vanessa L', 'VL', 'Merker'],
#    ['Ann M', 'AM', 'Neumeyer'],
#    ['Elmer E', 'EE', 'van Eeghen'],
#    ['Ronald L', 'RL', 'Thibert'],
#    ['Andrew J', 'AJ', 'Cole'],
#    ['Fawn A', 'FA', 'Leigh'],
#    ['Scott R', 'SR', 'Plotkin'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2012',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/23205844',
#   'abstract': ['As relationships between autistic traits, epilepsy, and cognitive functioning remain poorly understood, these associations were explored in the biologically related disorders tuberous sclerosis complex (TSC), neurofibromatosis type 1 (NF1), and epilepsy.',
#    'The Social Responsiveness Scale (SRS), a quantitative measure of autistic traits, was distributed to caregivers or companions of patients with TSC, NF1, and childhood-onset epilepsy of unknown cause (EUC), and these results were compared with SRS data from individuals with idiopathic autism spectrum disorders (ASDs) and their unaffected siblings. Scores and trait profiles of autistic features were compared with cognitive outcomes, epilepsy variables, and genotype.',
#    'A total of 180 SRS questionnaires were completed in the TSC, NF1, and EUC outpatient clinics at the Massachusetts General Hospital (90 females, 90 males; mean age 21 y, range 4-63 y), and SRS data from 210 patients with ASD recruited from an autism research collaboration (167 males, 43 females; mean age 9 y, range 4-22 y) and 130 unaffected siblings were available. Regression models showed a significant association between SRS scores and intelligence outcomes (p<0.001) and various seizure variables (p<0.02), but not with a specific underlying disorder or genotype. The level of autistic features was strongly associated with intelligence outcomes in patients with TSC and epilepsy (p<0.01); in patients with NF1 these relationships were weaker (p=0.25). For all study groups, autistic trait subdomains covaried with neurocognitive comorbidity, with endophenotypes similar to that of idiopathic autism.',
#    'Our data show that in TSC and childhood-onset epilepsy, the severity and phenotype of autistic features are inextricably linked with intelligence and epilepsy outcomes. Such relationships were weaker for individuals with NF1. Findings suggest that ASDs are not specific in these conditions.']},
#  {'title': 'Central TSC2 missense mutations are associated with a reduced risk of infantile spasms.',
#   'pmid': '22867869',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Multicenter Study'],
#   'journal_info_list': ['Epilepsy research',
#    '1872-6844',
#    'Electronic',
#    'Epilepsy Res.'],
#   'author_list': [['Agnies M', 'AM', 'van Eeghen'],
#    ['Mark', 'M', 'Nellist'],
#    ['Elmer E', 'EE', 'van Eeghen'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2012',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/22867869',
#   'abstract': ['Tuberous sclerosis complex (TSC) is an autosomal dominant syndrome with a variable neurocognitive phenotype. Recently, different intelligence profiles were observed for distinct mutation types and locations, suggesting that individuals with missense mutations represent a subgroup with milder neurocognitive outcomes. We applied these recent insights to the analysis of the epilepsy phenotype in a large cohort of patients with TSC. Associations between genotype and a history of epilepsy and/or infantile spasms (IS) were explored retrospectively, using data from 478 TSC patients from the databases of the Tuberous Sclerosis Alliance and the Herscot Center at Massachusetts General Hospital. Absolute and relative risks for IS and other types of epilepsy were calculated for various mutation classes, selected according to type and location. As expected, TSC2 mutations were associated with a significantly higher occurrence of IS and other epilepsy types. However, missense mutations located in the central region of TSC2 (exons 23-33) were associated with a significantly reduced incidence of IS. Our study further delineates the epilepsy phenotype in TSC patients. Identifying distinct epilepsy phenotypes for specific mutation subgroups may help identify relevant biomarkers and assist clinicians in making treatment decisions.']},
#  {'title': 'Genotype and cognitive phenotype of patients with tuberous sclerosis complex.',
#   'pmid': '22189265',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['European journal of human genetics : EJHG',
#    '1476-5438',
#    'Electronic',
#    'Eur. J. Hum. Genet.'],
#   'author_list': [['Agnies M', 'AM', 'van Eeghen'],
#    ['Margaux E', 'ME', 'Black'],
#    ['Margaret B', 'MB', 'Pulsifer'],
#    ['David J', 'DJ', 'Kwiatkowski'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2011',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/22189265',
#   'abstract': ['Tuberous sclerosis complex (TSC) is an autosomal dominant, multisystem disorder, which affects 1 in 6000 people. About half of these patients are affected by mental retardation, which has been associated with TSC2 mutations, epilepsy severity and tuber burden. The bimodal intelligence distribution in TSC populations suggests the existence of subgroups with distinct pathophysiologies, which remain to be identified. Furthermore, it is unknown if heterozygous germline mutations in TSC2 can produce the neurocognitive phenotype of TSC independent of epilepsy and tubers. Genotype-phenotype correlations may help to determine risk profiles and select patients for targeted treatments. A retrospective chart review was performed, including a large cohort of 137 TSC patients who received intelligence assessment and genetic mutation analysis. The distribution of intellectual outcomes was investigated for selected genotypes. Genotype-neurocognitive phenotype correlations were performed and associations between specific germline mutations and intellectual outcomes were compared. Results showed that TSC1 mutations in the tuberin interaction domain were significantly associated with lower intellectual outcomes (P<0.03), which was also the case for TSC2 protein-truncating and hamartin interaction domain mutations (both P<0.05). TSC2 missense mutations and small in-frame deletions were significantly associated with higher IQ/DQs (P<0.05). Effects related to the mutation location within the TSC2 gene were found. These findings suggest that TSC2 protein-truncating mutations and small in-frame mutations are associated with distinctly different intelligence profiles, providing further evidence that different types and locations of TSC germline mutations may be associated with distinct neurocognitive phenotypes.']},
#  {'title': 'Metaplastic bone in a cortical tuber of a young patient with tuberous sclerosis complex.',
#   'pmid': '21536642',
#   'keywords': [],
#   'pub_type_list': ['Case Reports',
#    'Journal Article',
#    'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['Neurology', '1526-632X', 'Electronic', 'Neurology'],
#   'author_list': [['A', 'A', 'Gallagher'],
#    ['A', 'A', 'Kovach'],
#    ['A', 'A', 'Stemmer-Rachamimov'],
#    ['A E', 'AE', 'Rosenberg'],
#    ['E', 'E', 'Eskandar'],
#    ['E A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2011',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/21536642',
#   'abstract': []},
#  {'title': 'The contribution of functional near-infrared spectroscopy (fNIRS) to the presurgical assessment of language function in children.',
#   'pmid': '21511328',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Review'],
#   'journal_info_list': ['Brain and language',
#    '1090-2155',
#    'Electronic',
#    'Brain Lang'],
#   'author_list': [['Anne', 'A', 'Gallagher'],
#    ['Renée', 'R', 'Béland'],
#    ['Maryse', 'M', 'Lassonde']],
#   'affil_list': [],
#   'pubdate': '2011',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/21511328',
#   'abstract': ['Before performing neurosurgery, an exhaustive presurgical assessment is required, usually including an investigation of language cerebral lateralization. Among the available procedures, the intracarotid amobarbital test (IAT) was formerly the most widely used. However, this procedure has many limitations: it is invasive and potentially traumatic, especially for children. To overcome these limitations, neuroimaging techniques such as functional magnetic resonance imaging (fMRI) have been used. Again, these methods are difficult to use with children, who must remain motionless during data acquisition. Functional near-infrared spectroscopy (fNIRS) is a noninvasive functional imaging technique that is easily applied to pediatric and cognitively limited patients. It has been used recently in epileptic children for presurgical assessment of expressive and receptive language brain lateralization. The aim of this review is to present the contribution of fNIRS to the presurgical assessment of language function in children with neurological diseases.']},
#  {'title': 'Progressive calcified tuber in a young male with tuberous sclerosis complex.',
#   'pmid': '21175459',
#   'keywords': [],
#   'pub_type_list': ['Case Reports',
#    'Journal Article',
#    "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Developmental medicine and child neurology',
#    '1469-8749',
#    'Electronic',
#    'Dev Med Child Neurol'],
#   'author_list': [['Anne', 'A', 'Gallagher'],
#    ['Neel', 'N', 'Madan'],
#    ['Anat', 'A', 'Stemmer-Rachamimov'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2010',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/21175459',
#   'abstract': ['Tubers are the most common brain lesions in tuberous sclerosis complex (TSC), and typically remain stable in size and appearance. We present the case of a young male with global developmental impairment and autistic features as well as multiple and mixed daily seizures. The patient had a prominent right frontal cortical tuber characterized by a calcified component, which changed on consecutive magnetic resonance imaging between the age of 4 and 11 years, at which time the patient underwent a lesionectomy. A poor long-term outcome is reported since the patient presents an intractable mixed seizure disorder status post-epilepsy surgery and no significant neuropsychological improvements. Histopathology findings show typical characteristics of tubers in TSC as well as numerous calcifications within the resected nodular lesion. This case supports the notion that tubers with calcified components are not necessarily static lesions and can change with time. Investigation of the relationship between the presence of calcification in tubers and epileptogenecity in a large group of patients would provide insights into the pathogenesis of the seizures and cognitive impairment and hopefully, eventually provide better treatment options for patients with TSC.']},
#  {'title': 'Tuberous sclerosis complex: diagnostic challenges, presenting symptoms, and commonly missed signs.',
#   'pmid': '21173003',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['Pediatrics', '1098-4275', 'Electronic', 'Pediatrics'],
#   'author_list': [['Brigid A', 'BA', 'Staley'],
#    ['Emily A', 'EA', 'Vail'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2010',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/21173003',
#   'abstract': ['To describe presenting symptoms and signs according to age group in a cohort of 243 patients with tuberous sclerosis complex (TSC) and identify earlier symptoms and signs that did not lead to immediate diagnosis.',
#    "We performed a retrospective chart review for 278 patients with TSC who were examined at Children's Hospital Boston in Massachusetts and at the Herscot Center for Tuberous Sclerosis Complex, Massachusetts General Hospital. The presenting symptom or sign was the first symptom or sign to cause suspicion for TSC and lead to diagnosis. Missed symptoms or signs were those that were documented in the patient's chart but did not immediately lead to diagnosis.",
#    'There were 243 patients for whom there were sufficient data for inclusion in this study. Patients were diagnosed with TSC at ages ranging from birth to 73 years. The average age at diagnosis was 7.5 years. Of the patients, 81% were diagnosed before the age of 10. Diagnosis during adolescence and adulthood was not uncommon. The most common presenting symptoms and signs included new onset of seizures, history of seizures, infantile spasms, family history of TSC, cardiac rhabdomyomas, and hypopigmented macules. Of the patients, 39% reported missed symptoms or signs of TSC, most commonly seizures (including infantile spasms) and dermatologic features.',
#    'Many patients had symptoms or signs of TSC that did not lead to immediate diagnosis. Clinicians should be aware of the myriad potential presenting symptoms and signs of TSC. Early diagnosis may reduce morbidity and mortality.']},
#  {'title': 'Characterizing sleep disorders of adults with tuberous sclerosis complex: a questionnaire-based study and review.',
#   'pmid': '21130696',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', 'Research Support, N.I.H., Extramural'],
#   'journal_info_list': ['Epilepsy & behavior : E&B',
#    '1525-5069',
#    'Electronic',
#    'Epilepsy Behav'],
#   'author_list': [['Agnies M', 'AM', 'van Eeghen'],
#    ['Adam I', 'AI', 'Numis'],
#    ['Brigid A', 'BA', 'Staley'],
#    ['Samuel E', 'SE', 'Therrien'],
#    ['Ronald L', 'RL', 'Thibert'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2010',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/21130696',
#   'abstract': ['An adult cohort with tuberous sclerosis complex was investigated for the prevalence of sleep disturbances and the relationship with seizure variables, medication, and psychological functioning. Information on 35 adults was gathered using four questionnaires: Epworth Sleepiness Scale (ESS), Sleep and Epilepsy Questionnaire (SEQ), Sleep Diagnosis List (SDL), and Adult Self-Report Scale (ASR). In addition, clinical, genetic and electrophysiological data were collected. Of 35 respondents, 25 had a history of epilepsy. A subjective sleep disorder was found in 31% of the cohort. Insomnia scores showed a significant positive correlation with obstructive sleep apnea syndrome and restless legs syndrome scores. Significant correlations were found between daytime sleepiness and scores on depression, antisocial behavior, and use of mental health medication. A subgroup using antiepileptic medication showed high correlations between daytime sleepiness, attention deficits, and anxiety scores.']},
#  {'title': 'Managing and understanding epilepsy in tuberous sclerosis complex.',
#   'pmid': '20331728',
#   'keywords': [],
#   'pub_type_list': ['Journal Article'],
#   'journal_info_list': ['Epilepsia', '1528-1167', 'Electronic', 'Epilepsia'],
#   'author_list': [['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': ['Carol and James Herscot Center for TSC, Department of Neurology, Massachusetts General Hospital, Boston, Massachusetts, USA. ethiele@partners.org'],
#   'pubdate': '2010',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/20331728',
#   'abstract': []},
#  {'title': 'Associations between electroencephalographic and magnetic resonance imaging findings in tuberous sclerosis complex.',
#   'pmid': '19783123',
#   'keywords': [],
#   'pub_type_list': ['Journal Article', "Research Support, Non-U.S. Gov't"],
#   'journal_info_list': ['Epilepsy research',
#    '1872-6844',
#    'Electronic',
#    'Epilepsy Res.'],
#   'author_list': [['Anne', 'A', 'Gallagher'],
#    ['Catherine J', 'CJ', 'Chu-Shore'],
#    ['Maria A', 'MA', 'Montenegro'],
#    ['Philippe', 'P', 'Major'],
#    ['Daniel J', 'DJ', 'Costello'],
#    ['David A', 'DA', 'Lyczkowski'],
#    ['David', 'D', 'Muzykewicz'],
#    ['Colin', 'C', 'Doherty'],
#    ['Elizabeth A', 'EA', 'Thiele']],
#   'affil_list': [],
#   'pubdate': '2009',
#   'link': 'https://www.ncbi.nlm.nih.gov/pubmed/19783123',
#   'abstract': ['Nearly 90% of patients with tuberous sclerosis complex (TSC) develop epilepsy; however the mechanisms of epileptogenesis remain unclear. Some cortical tubers are thought to be epileptogenic while others are not. This study aimed to evaluate whether tuber burden, size or type seen on magnetic resonance imaging (MRI) co-registers with interictal epileptiform discharges on electroencephalogram (EEG). EEG and MRI data from 69 patients with TSC were reviewed by dividing the cerebrum into four quadrants. Quadrants containing greatest tuber burden, largest tuber, calcified tubers, cyst-like tubers, and no tubers were identified on MRI. For EEG analysis, spikes and sharp waves were counted and averaged to a value per minute, and each quadrant was assigned a score. MRI and EEG findings were compared in each patient. The presence of a cyst-like tuber in a quadrant correlated with a higher incidence of epileptiform activity in the same quadrant (p=0.002). This finding supports the notion that cyst-like cortical tubers may contribute to the more severe epilepsy profile seen in TSC patients with these lesions. Quadrants containing greatest tuber burden, largest tubers, and calcified tubers were not predictive of regional interictal epileptiform activity. Furthermore, quadrants without any apparent tuber co-registered with interictal epileptiform discharges in two patients, suggesting a multifactorial component of epileptogenicity in TSC.']}]

# %%
affiliations_result
# Out:
# [{'author': ['Annelise', 'A', 'Madison'],
#   'affiliation': ['Institute for Behavioral Medicine Research, The Ohio State University College of Medicine, United States.',
#    'Department of Psychology, The Ohio State University, United States.'],
#   'pmid': '32395568'},
#  {'author': ['Janice K', 'JK', 'Kiecolt-Glaser'],
#   'affiliation': ['Institute for Behavioral Medicine Research, The Ohio State University College of Medicine, United States.',
#    'Department of Psychiatry and Behavioral Health, The Ohio State University College of Medicine, United States.'],
#   'pmid': '32395568'},
#  {'author': ['Craig', 'C', 'Friesen'],
#   'affiliation': ["Division of Gastroenterology, Hepatology, and Nutrition, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA. cfriesen@cmh.edu."],
#   'pmid': '32393272'},
#  {'author': ['Meenal', 'M', 'Singh'],
#   'affiliation': ["Division of Gastroenterology, Hepatology, and Nutrition, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA."],
#   'pmid': '32393272'},
#  {'author': ['Vivekanand', 'V', 'Singh'],
#   'affiliation': ["Department of Pathology and Laboratory Medicine, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, Missouri, USA."],
#   'pmid': '32393272'},
#  {'author': ['Jennifer V', 'JV', 'Schurman'],
#   'affiliation': ["Division of Developmental and Behavioral Sciences, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA."],
#   'pmid': '32393272'},
#  {'author': ['Owen M', 'OM', 'Vega'],
#   'affiliation': ['Pathology and Laboratory Medicine, University of California, Los Angeles, USA.'],
#   'pmid': '32393071'},
#  {'author': ['Shaheen', 'S', 'Abkenari'],
#   'affiliation': ['Pathology and Laboratory Medicine, University of California, Los Angeles, USA.'],
#   'pmid': '32393071'},
#  {'author': ['Zhen', 'Z', 'Tong'],
#   'affiliation': ['Pathology and Laboratory Medicine, University of California, Los Angeles, USA.'],
#   'pmid': '32393071'},
#  {'author': ['Austin', 'A', 'Tedman'],
#   'affiliation': ['Pathology and Laboratory Medicine, University of California, Los Angeles, USA.'],
#   'pmid': '32393071'},
#  {'author': ['Sara', 'S', 'Huerta-Yepez'],
#   'affiliation': ['Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#    'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.'],
#   'pmid': '32393071'},
#  {'author': ['Bonan', 'B', 'Liu'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Jiayuan', 'J', 'Kou'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Fuyan', 'F', 'Li'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Da', 'D', 'Huo'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Jiaran', 'J', 'Xu'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Xiaoxi', 'X', 'Zhou'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Dehao', 'D', 'Meng'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Murtaza', 'M', 'Ghulam'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Bobkov', 'B', 'Artyom'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Xu', 'X', 'Gao'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#    'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#    'Translational Medicine Center of Northern China, Harbin 150081, China.',
#    'Heilongjiang Provincial key Laboratory of Genetically Modified Model Animal, Harbin Medical University, Ministry of Education, Harbin 150081, China.',
#    'China Key Laboratory of Preservation of Human Genetic Resources and Disease Control in China (Harbin Medical University), Ministry of Education, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Ning', 'N', 'Ma'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#    'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#    'Translational Medicine Center of Northern China, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Dong', 'D', 'Han'],
#   'affiliation': ['Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#    'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#    'Translational Medicine Center of Northern China, Harbin 150081, China.'],
#   'pmid': '32392535'},
#  {'author': ['Bolu', 'B', 'Sun'],
#   'affiliation': ['School of Pharmacy, Lanzhou University, Lanzhou 730000, China.'],
#   'pmid': '32388438'},
#  {'author': ['Dai', 'D', 'Li'],
#   'affiliation': ['School of Pharmacy, Lanzhou University, Lanzhou 730000, China.'],
#   'pmid': '32388438'},
#  {'author': ['Xiaohui', 'X', 'Hou'],
#   'affiliation': ['School of Pharmacy, Lanzhou University, Lanzhou 730000, China.'],
#   'pmid': '32388438'},
#  {'author': ['Wuyan', 'W', 'Li'],
#   'affiliation': ['Center for Inflammation, Translational and Clinical Lung Research, Temple University School of Medicine, Philadelphia, PA, USA.'],
#   'pmid': '32388438'},
#  {'author': ['Yuqiang', 'Y', 'Gou'],
#   'affiliation': ["Center for Disease Prevention and Control in Northwest Theater of the Chinese People's Liberation Army, Lanzhou 730000, China."],
#   'pmid': '32388438'},
#  {'author': ['Fangdi', 'F', 'Hu'],
#   'affiliation': ['School of Pharmacy, Lanzhou University, Lanzhou 730000, China. Electronic address: hufd@lzu.edu.cn.'],
#   'pmid': '32388438'},
#  {'author': ['Wen', 'W', 'Li'],
#   'affiliation': ['School of Pharmacy, Lanzhou University, Lanzhou 730000, China. Electronic address: lwen@lzu.edu.cn.'],
#   'pmid': '32388438'},
#  {'author': ['Xiaofeng', 'X', 'Shi'],
#   'affiliation': ['Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.'],
#   'pmid': '32388438'},
#  {'author': ['David R', 'DR', 'Goldsmith'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322.'],
#   'pmid': '32387344'},
#  {'author': ['Mandakh', 'M', 'Bekhbat'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322.'],
#   'pmid': '32387344'},
#  {'author': ['Ngoc-Anh', 'NA', 'Le'],
#   'affiliation': ['Biomarker Core Laboratory, Foundation for Atlanta Veterans Education and Research, Atlanta VAHSC, Decatur, GA, 30033.'],
#   'pmid': '32387344'},
#  {'author': ['Xiangchuan', 'X', 'Chen'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322.'],
#   'pmid': '32387344'},
#  {'author': ['Bobbi J', 'BJ', 'Woolwine'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322.'],
#   'pmid': '32387344'},
#  {'author': ['Zhihao', 'Z', 'Li'],
#   'affiliation': ['School of Psychology, Shenzhen University, Shenzhen, Guangdong 518060, China; Center for Brain Disorders and Cognitive Neuroscience, Shenzhen University, Shenzhen, Guangdong 518060, China. Electronic address: zhihao_li@szu.edu.cn.'],
#   'pmid': '32387344'},
#  {'author': ['Ebrahim', 'E', 'Haroon'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: eharoon@emory.edu.'],
#   'pmid': '32387344'},
#  {'author': ['Jennifer C', 'JC', 'Felger'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.'],
#   'pmid': '32387344'},
#  {'author': ['Hai-Lian', 'HL', 'Yuan'],
#   'affiliation': ["Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China."],
#   'pmid': '32387235'},
#  {'author': ['Yun-Li', 'YL', 'Zhao'],
#   'affiliation': ["Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China."],
#   'pmid': '32387235'},
#  {'author': ['Cai-Feng', 'CF', 'Ding'],
#   'affiliation': ["State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China."],
#   'pmid': '32387235'},
#  {'author': ['Pei-Feng', 'PF', 'Zhu'],
#   'affiliation': ["State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China; University of Chinese Academy of Sciences, Beijing, 100049, People's Republic of China."],
#   'pmid': '32387235'},
#  {'author': ['Qiong', 'Q', 'Jin'],
#   'affiliation': ["State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China; University of Chinese Academy of Sciences, Beijing, 100049, People's Republic of China."],
#   'pmid': '32387235'},
#  {'author': ['Ya-Ping', 'YP', 'Liu'],
#   'affiliation': ["State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: xdluo@mail.kib.ac.cn."],
#   'pmid': '32387235'},
#  {'author': ['Zhong-Tao', 'ZT', 'Ding'],
#   'affiliation': ["Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China. Electronic address: liuyaping@mail.kib.ac.cn."],
#   'pmid': '32387235'},
#  {'author': ['Xiao-Dong', 'XD', 'Luo'],
#   'affiliation': ["Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn."],
#   'pmid': '32387235'},
#  {'author': ['Norwin', 'N', 'Kubick'],
#   'affiliation': ['Department of Biochemistry and Molecular Cell Biology (IBMZ), University Medical Center Hamburg-Eppendorf, Martinistraße 52, 20246 Hamburg, Germany.'],
#   'pmid': '32380663'},
#  {'author': ['Marta', 'M', 'Pajares'],
#   'affiliation': ['Instituto de Investigaciones Biomédicas Alberto Sols (CSIC-UAM), 28029 Madrid, Spain.'],
#   'pmid': '32380663'},
#  {'author': ['Ioana', 'I', 'Enache'],
#   'affiliation': ['Department of radiology, Victor Babes National Institute of Pathology, 99-101 Splaiul Independenței, 050096 Bucharest, Romania.'],
#   'pmid': '32380663'},
#  {'author': ['Gina', 'G', 'Manda'],
#   'affiliation': ['Department of radiology, Victor Babes National Institute of Pathology, 99-101 Splaiul Independenței, 050096 Bucharest, Romania.'],
#   'pmid': '32380663'},
#  {'author': ['Michel-Edwar', 'ME', 'Mickael'],
#   'affiliation': ['PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#    'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.'],
#   'pmid': '32380663'},
#  {'author': ['I', 'I', 'Lewkowich'],
#   'affiliation': ["Division of Immunobiology, Children's Hospital Medical Center, Cincinnati OH, 45220; Department of Pediatrics, University of Cincinnati, Cincinnati OH, 45220."],
#   'pmid': '32380274'},
#  {'author': ['R', 'R', 'Ahlbrand'],
#   'affiliation': ['Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220.'],
#   'pmid': '32380274'},
#  {'author': ['E', 'E', 'Johnson'],
#   'affiliation': ['Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220.'],
#   'pmid': '32380274'},
#  {'author': ['J', 'J', 'McAlees'],
#   'affiliation': ["Division of Immunobiology, Children's Hospital Medical Center, Cincinnati OH, 45220."],
#   'pmid': '32380274'},
#  {'author': ['N', 'N', 'Nawreen'],
#   'affiliation': ['Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220.'],
#   'pmid': '32380274'},
#  {'author': ['R', 'R', 'Raman'],
#   'affiliation': ['Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220.'],
#   'pmid': '32380274'},
#  {'author': ['I', 'I', 'Lingel'],
#   'affiliation': ["Division of Immunobiology, Children's Hospital Medical Center, Cincinnati OH, 45220."],
#   'pmid': '32380274'},
#  {'author': ['J', 'J', 'Hargis'],
#   'affiliation': ["Division of Immunobiology, Children's Hospital Medical Center, Cincinnati OH, 45220."],
#   'pmid': '32380274'},
#  {'author': ['C', 'C', 'Hoover'],
#   'affiliation': ['Neuroscience Undergraduate Program, University of Cincinnati, Cincinnati OH, 45220.'],
#   'pmid': '32380274'},
#  {'author': ['R', 'R', 'Sah'],
#   'affiliation': ['Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.'],
#   'pmid': '32380274'},
#  {'author': ['Hartej', 'H', 'Gill'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Institute of Medical Science, University of Toronto, Toronto, ON, Canada. Electronic address: hartej.gill@mail.utoronto.ca.'],
#   'pmid': '32379599'},
#  {'author': ['Sabine', 'S', 'El-Halabi'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Amna', 'A', 'Majeed'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Barjot', 'B', 'Gill'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Leanna M W', 'LMW', 'Lui'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Rodrigo B', 'RB', 'Mansur'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Orly', 'O', 'Lipsitz'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Nelson B', 'NB', 'Rodrigues'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Lee', 'L', 'Phan'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Institute of Medical Science, University of Toronto, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['David', 'D', 'Chen-Li'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Roger S', 'RS', 'McIntyre'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Institute of Medical Science, University of Toronto, Toronto, ON, Canada; Department of Pharmacology, University of Toronto, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Joshua Daniel', 'JD', 'Rosenblat'],
#   'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.'],
#   'pmid': '32379599'},
#  {'author': ['Geoffrey', 'G', 'Hackett'],
#   'affiliation': ['Department of Urology, University Hospitals Birmingham NHS Foundation Trust, England, UK.',
#    'School of Health and Life Sciences, Aston University, England, UK. hackettgeoff@gmail.com.'],
#   'pmid': '32378365'},
#  {'author': ['Tahir', 'T', 'Ali'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.'],
#   'pmid': '32375205'},
#  {'author': ['Shafiq Ur', 'SU', 'Rahman'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.',
#    'Department of Pharmacy, Shaheed Benazir Bhutto University, Sheringal Dir, KP, Pakistan.'],
#   'pmid': '32375205'},
#  {'author': ['Qiang', 'Q', 'Hao'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.'],
#   'pmid': '32375205'},
#  {'author': ['Weifen', 'W', 'Li'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.'],
#   'pmid': '32375205'},
#  {'author': ['Zizhen', 'Z', 'Liu'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.'],
#   'pmid': '32375205'},
#  {'author': ['Fawad', 'F', 'Ali Shah'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.',
#    'Department of Pharmacology, Riphah Institute of Pharmaceutical Sciences, Islamabad, Pakistan.'],
#   'pmid': '32375205'},
#  {'author': ['Iram', 'I', 'Murtaza'],
#   'affiliation': ['Signal Transduction Lab, Department of Biochemistry, Faculty of Biological Sciences, Quaid-I-Azam University, Islamabad, Pakistan.'],
#   'pmid': '32375205'},
#  {'author': ['Zaijun', 'Z', 'Zhang'],
#   'affiliation': ['International Cooperative Laboratory of Traditional Chinese Medicine Modernization and Innovative Drug Development of Chinese Ministry of Education (MOE), Jinan University College of Pharmacy, Guangzhou, China.'],
#   'pmid': '32375205'},
#  {'author': ['Xifei', 'X', 'Yang'],
#   'affiliation': ['Key Laboratory of Modern Toxicology of Shenzhen, Shenzhen Center for Disease Control and Prevention, No. 8, Longyuan Road, Nanshan District, Shenzhen, China, 518055.'],
#   'pmid': '32375205'},
#  {'author': ['Gongping', 'G', 'Liu'],
#   'affiliation': ['Department of Pathophysiology, School of Basic Medicine and the Collaborative Innovation Center for Brain Science, Key Laboratory of Ministry of Education of China and Hubei Province for Neurological Disorders, Tongji Medical College, Huazhong University of Science and Technology, Wuhan, China.',
#    'Co-innovation Center of Neuroregeneration, Nantong University, Nantong, JS, China.'],
#   'pmid': '32375205'},
#  {'author': ['Shupeng', 'S', 'Li'],
#   'affiliation': ['State Key Laboratory of Oncogenomics, School of Chemical Biology and Biotechnology, Peking University Shenzhen Graduate School, Shenzhen, 518055, China.',
#    'Department of Psychiatry, University of Toronto, Toronto, ON, Canada.'],
#   'pmid': '32375205'},
#  {'author': ['Michele L', 'ML', 'Okun'],
#   'affiliation': ['BioFrontiers Center, University of Colorado, Colorado Springs, 1420 Austin Bluffs Parkway, Colorado Springs, CO, 80918, USA. mokun@uccs.edu.',
#    'Department of Psychology, University of Colorado, Colorado Springs, 1420 Austin Bluffs Parkway, Colorado Springs, CO, 80918, USA. mokun@uccs.edu.'],
#   'pmid': '32372169'},
#  {'author': ['Vanessa', 'V', 'Obetz'],
#   'affiliation': ['Department of Psychology, University of Colorado, Colorado Springs, 1420 Austin Bluffs Parkway, Colorado Springs, CO, 80918, USA.'],
#   'pmid': '32372169'},
#  {'author': ['Leilani', 'L', 'Feliciano'],
#   'affiliation': ['Department of Psychology, University of Colorado, Colorado Springs, 1420 Austin Bluffs Parkway, Colorado Springs, CO, 80918, USA.'],
#   'pmid': '32372169'},
#  {'author': ['Fahime', 'F', 'Zavvari'],
#   'affiliation': ['Department of Physiology, Faculty of Medicine, Iran University of Medical Science, Tehran, Iran.'],
#   'pmid': '32371049'},
#  {'author': ['Arezo', 'A', 'Nahavandi'],
#   'affiliation': ['Department of Physiology, Faculty of Medicine, Iran University of Medical Science, Tehran, Iran; Department of Neuroscience, Faculty of Advanced Technologies in Medicine, Iran University of Medical Science, Tehran, Iran; Neuroscience Research Center, Iran University of Medical Science, Tehran, Iran. Electronic address: arezonahavandi_1999@yahoo.com.'],
#   'pmid': '32371049'},
#  {'author': ['Ali', 'A', 'Shahbazi'],
#   'affiliation': ['Department of Neuroscience, Faculty of Advanced Technologies in Medicine, Iran University of Medical Science, Tehran, Iran.'],
#   'pmid': '32371049'},
#  {'author': ['Giulia', 'G', 'Lisi'],
#   'affiliation': ['Department of Systems Medicine University of Rome Tor Vergata, Rome. Italy.'],
#   'pmid': '32370709'},
#  {'author': ['Michele', 'M', 'Ribolsi'],
#   'affiliation': ['Department of Systems Medicine University of Rome Tor Vergata, Rome. Italy.'],
#   'pmid': '32370709'},
#  {'author': ['Alberto', 'A', 'Siracusano'],
#   'affiliation': ['Department of Systems Medicine University of Rome Tor Vergata, Rome. Italy.'],
#   'pmid': '32370709'},
#  {'author': ['Cinzia', 'C', 'Niolu'],
#   'affiliation': ['Department of Systems Medicine University of Rome Tor Vergata, Rome. Italy.'],
#   'pmid': '32370709'},
#  {'author': ['Yue', 'Y', 'Tong'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Huiling', 'H', 'Fu'],
#   'affiliation': ["The First People's Hospital of Yinchuan, Ningxia Medical University, Ningxia 750004, China."],
#   'pmid': '32364698'},
#  {'author': ['Changbo', 'C', 'Xia'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Wen', 'W', 'Song'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Yuanjie', 'Y', 'Li'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Jianjun', 'J', 'Zhao'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Xia', 'X', 'Zhang'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Xiaojuan', 'X', 'Gao'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Jingjiao', 'J', 'Yong'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Quanxia', 'Q', 'Liu'],
#   'affiliation': ['The General Hospital of Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Caiyan', 'C', 'Yang'],
#   'affiliation': ["The First People's Hospital of Yinchuan, Ningxia Medical University, Ningxia 750004, China."],
#   'pmid': '32364698'},
#  {'author': ['Hanqing', 'H', 'Wang'],
#   'affiliation': ['College of Pharmacy, Ningxia Medical University, Ningxia 750004, China.',
#    'Ningxia Research Center of Modern Hui Medicine Engineering and Technology, Ningxia Medical University, Ningxia 750004, China.',
#    'Key Laboratory of Hui Ethnic Medicine Modernization, Ministry of Education, Ningxia Medical University, Ningxia 750004, China.'],
#   'pmid': '32364698'},
#  {'author': ['Christine F', 'CF', 'Gelin'],
#   'affiliation': ['Discovery Chemistry, Discovery Sciences, Janssen Research and Development, LLC, San Diego, CA, United States. Electronic address: cgelin@its.jnj.com.'],
#   'pmid': '32362329'},
#  {'author': ['Anindya', 'A', 'Bhattacharya'],
#   'affiliation': ['Neuroscience, Janssen Research and Development, LLC, San Diego, CA, United States.'],
#   'pmid': '32362329'},
#  {'author': ['Michael A', 'MA', 'Letavic'],
#   'affiliation': ['Discovery Chemistry, Discovery Sciences, Janssen Research and Development, LLC, San Diego, CA, United States.'],
#   'pmid': '32362329'},
#  {'author': ['Alex R', 'AR', 'Jenkins'],
#   'affiliation': ['Division of Respiratory Medicine, University of Nottingham, UK.',
#    'Lincoln International Institute for Rural Health, University of Lincoln, Lincoln, UK.'],
#   'pmid': '32362176'},
#  {'author': ['Neil S', 'NS', 'Holden'],
#   'affiliation': ['School of Life Sciences, University of Lincoln, Lincoln, UK.'],
#   'pmid': '32362176'},
#  {'author': ['Luke P', 'LP', 'Gibbons'],
#   'affiliation': ['Countywide Community Respiratory Service, Lincolnshire Community Health Services NHS Trust, Lincoln, UK.'],
#   'pmid': '32362176'},
#  {'author': ['Arwel W', 'AW', 'Jones'],
#   'affiliation': ['Lincoln International Institute for Rural Health, University of Lincoln, Lincoln, UK.'],
#   'pmid': '32362176'},
#  {'author': ['Tianpeng', 'T', 'Zheng'],
#   'affiliation': ['From the Departments of Endocrinology and Metabolism (Zheng, Xiao, Hu, Pan, Chen) and Urology (Ge), The Second Affiliated Hospital of Guilin Medical University; Department of Epidemiology and Health Statistics (Qin), Guilin Medical University, Guilin, Guangxi; Department of Human Anatomy (Chen), Southwest Medical University, Luzhou; and Department of Endocrinology and Metabolism (Tian, Gao), West China Hospital, Chengdu, Sichuan, China.'],
#   'pmid': '32358323'},
#  {'author': ['Bo', 'B', 'Ge'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Linyuan', 'L', 'Qin'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Bo', 'B', 'Chen'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Li', 'L', 'Tian'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Yun', 'Y', 'Gao'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Liuping', 'L', 'Xiao'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Xueping', 'X', 'Hu'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Haidong', 'H', 'Pan'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Yujie', 'Y', 'Chen'], 'affiliation': [], 'pmid': '32358323'},
#  {'author': ['Daniel', 'D', 'González-Nieto'],
#   'affiliation': ['Center for Biomedical Technology, Universidad Politécnica de Madrid, 28040 Madrid, Spain.',
#    'Departamento de Tecnología Fotónica y Bioingeniería, ETSI Telecomunicaciones, Universidad Politécnica de Madrid, 28040 Madrid, Spain.',
#    'Biomedical Research Networking Center in Bioengineering Biomaterials and Nanomedicine (CIBER-BBN), 28029 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['Rocío', 'R', 'Fernández-Serra'],
#   'affiliation': ['Center for Biomedical Technology, Universidad Politécnica de Madrid, 28040 Madrid, Spain.',
#    'Departamento de Tecnología Fotónica y Bioingeniería, ETSI Telecomunicaciones, Universidad Politécnica de Madrid, 28040 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['José', 'J', 'Pérez-Rigueiro'],
#   'affiliation': ['Center for Biomedical Technology, Universidad Politécnica de Madrid, 28040 Madrid, Spain.',
#    'Biomedical Research Networking Center in Bioengineering Biomaterials and Nanomedicine (CIBER-BBN), 28029 Madrid, Spain.',
#    'Departamento de Ciencia de Materiales, ETSI Caminos, Canales y Puertos, Universidad Politécnica de Madrid, 28040 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['Fivos', 'F', 'Panetsos'],
#   'affiliation': ['Neurocomputing and Neurorobotics Research Group: Faculty of Biology and Faculty of Optics, Universidad Complutense de Madrid, 28040 Madrid, Spain.',
#    'Brain Plasticity Group, Health Research Institute of the Hospital Clínico San Carlos (IdISSC), 28040 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['Ricardo', 'R', 'Martinez-Murillo'],
#   'affiliation': ['Department of Translational Neuroscience, Instituto Cajal (CSIC), 28002 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['Gustavo V', 'GV', 'Guinea'],
#   'affiliation': ['Center for Biomedical Technology, Universidad Politécnica de Madrid, 28040 Madrid, Spain.',
#    'Biomedical Research Networking Center in Bioengineering Biomaterials and Nanomedicine (CIBER-BBN), 28029 Madrid, Spain.',
#    'Departamento de Ciencia de Materiales, ETSI Caminos, Canales y Puertos, Universidad Politécnica de Madrid, 28040 Madrid, Spain.'],
#   'pmid': '32357544'},
#  {'author': ['Suzi', 'S', 'Hong'],
#   'affiliation': ['Department of Family Medicine & Public Health, University of California San Diego, USA; Department of Psychiatry, University of California San Diego, 9500 Gilman Dr. MC0804, La Jolla, California 92093-0804, USA. Electronic address: s1hong@health.ucsd.edu.'],
#   'pmid': '32353522'},
#  {'author': ['Edith', 'E', 'Chen'],
#   'affiliation': ['Northwestern University, Institute for Policy Research & Department of Psychology, Evanston, IL, USA. Electronic address: edith.chen@northwestern.edu.'],
#   'pmid': '32353517'},
#  {'author': ['Tianyi', 'T', 'Yu'],
#   'affiliation': ['University of Georgia, Center for Family Research, Athens, GA, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Rebekah', 'R', 'Siliezar'],
#   'affiliation': ['Northwestern University, Institute for Policy Research & Department of Psychology, Evanston, IL, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Jane N', 'JN', 'Drage'],
#   'affiliation': ['Northwestern University, Institute for Policy Research & Department of Psychology, Evanston, IL, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Johanna', 'J', 'Dezil'],
#   'affiliation': ['Northwestern University, Institute for Policy Research & Department of Psychology, Evanston, IL, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Gregory E', 'GE', 'Miller'],
#   'affiliation': ['Northwestern University, Institute for Policy Research & Department of Psychology, Evanston, IL, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Gene H', 'GH', 'Brody'],
#   'affiliation': ['University of Georgia, Center for Family Research, Athens, GA, USA.'],
#   'pmid': '32353517'},
#  {'author': ['Yi', 'Y', 'Liu'],
#   'affiliation': ['Department of Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.',
#    'Department of Gastroenterology, the Affiliated Hospital of Qingdao University, Qingdao, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Xunyi', 'X', 'Yuan'],
#   'affiliation': ['Department of General Surgery, Qilu Hospital of Shandong University, Jinan, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Lixiang', 'L', 'Li'],
#   'affiliation': ['Department of Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.',
#    'Laboratory of Translational Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Lin', 'L', 'Lin'],
#   'affiliation': ['Department of Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Xiuli', 'X', 'Zuo'],
#   'affiliation': ['Department of Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Yingzi', 'Y', 'Cong'],
#   'affiliation': ['Department of Microbiology and Immunology, University of Texas Medical Branch, Galveston, Texas, USA.',
#    'Department of Pathology, University of Texas Medical Branch, Galveston, Texas, USA.'],
#   'pmid': '32352710'},
#  {'author': ['Yanqing', 'Y', 'Li'],
#   'affiliation': ['Department of Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.',
#    'Laboratory of Translational Gastroenterology, Qilu Hospital of Shandong University, Jinan, Shandong, China.'],
#   'pmid': '32352710'},
#  {'author': ['Ana Paula Vargas', 'APV', 'Visentin'],
#   'affiliation': ['Instituto de Biotecnologia, Universidade de Caxias do Sul, Caxias do Sul, RS 95070 560, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Rafael', 'R', 'Colombo'],
#   'affiliation': ['Instituto de Biotecnologia, Universidade de Caxias do Sul, Caxias do Sul, RS 95070 560, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Ellen', 'E', 'Scotton'],
#   'affiliation': ['Laboratório de Psiquiatria Molecular, Hospital de Clínicas de Porto Alegre, Porto Alegre, RS, Brazil.',
#    'Programa de Pós-Graduação em Farmacologia e Terapêutica, Universidade Federal do Rio Grande do Sul, Porto Alegre, RS, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Débora Soligo', 'DS', 'Fracasso'],
#   'affiliation': ['Instituto de Biotecnologia, Universidade de Caxias do Sul, Caxias do Sul, RS 95070 560, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Adriane Ribeiro', 'AR', 'da Rosa'],
#   'affiliation': ['Laboratório de Psiquiatria Molecular, Hospital de Clínicas de Porto Alegre, Porto Alegre, RS, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Catia Santos', 'CS', 'Branco'],
#   'affiliation': ['Instituto de Biotecnologia, Universidade de Caxias do Sul, Caxias do Sul, RS 95070 560, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Mirian', 'M', 'Salvador'],
#   'affiliation': ['Instituto de Biotecnologia, Universidade de Caxias do Sul, Caxias do Sul, RS 95070 560, Brazil.'],
#   'pmid': '32351669'},
#  {'author': ['Theodore A', 'TA', 'Henderson'],
#   'affiliation': ['The Synaptic Space, Inc., Denver, CO, United States.',
#    'Neuro-Luminance, Inc., Denver, CO, United States.',
#    'Dr. Theodore Henderson, Inc., Denver, CO, United States.',
#    'International Society of Applied Neuroimaging, Denver, CO, United States.'],
#   'pmid': '32351416'},
#  {'author': ['Muriel J', 'MJ', 'van Lierop'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Private Practice, Toronto, ON, Canada.'],
#   'pmid': '32351416'},
#  {'author': ['Mary', 'M', 'McLean'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Private Practice, Toronto, ON, Canada.'],
#   'pmid': '32351416'},
#  {'author': ['John Michael', 'JM', 'Uszler'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    "Nuclear Medicine, Providence St. John's Health Center, Santa Monica, CA, United States.",
#    'Molecular and Medical Pharmacology, University of California, Los Angeles, Los Angeles, CA, United States.'],
#   'pmid': '32351416'},
#  {'author': ['John F', 'JF', 'Thornton'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Rossiter-Thornton Associates, Toronto, ON, Canada.'],
#   'pmid': '32351416'},
#  {'author': ['Yin-Hui', 'YH', 'Siow'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Nuclear Medicine, Southlake Regional Health Centre, Newmarket, ON, Canada.'],
#   'pmid': '32351416'},
#  {'author': ['Dan G', 'DG', 'Pavel'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'PathFinder Brain SPECT, Deerfield, IL, United States.'],
#   'pmid': '32351416'},
#  {'author': ['Joe', 'J', 'Cardaci'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Fremantle-School of Medicine, University of Notre Dame, Fremantle, WA, Australia.',
#    'Diagnostic Nuclear Medicine, Hollywood Private Hospital, Nedlands, WA, Australia.',
#    'Consultant Physician, Perth, WA, Australia.'],
#   'pmid': '32351416'},
#  {'author': ['Phil', 'P', 'Cohen'],
#   'affiliation': ['International Society of Applied Neuroimaging, Denver, CO, United States.',
#    'Nuclear Medicine, Lions Gate Hospital, Vancouver, BC, Canada.',
#    'Radiology, University of British Columbia, Vancouver, BC, Canada.'],
#   'pmid': '32351416'},
#  {'author': ['N V', 'NV', 'Pogosova'],
#   'affiliation': ['National Medical Research Center for Cardiology of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['Y M', 'YM', 'Yufereva'],
#   'affiliation': ['National Medical Research Center for Cardiology of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['N P', 'NP', 'Kachanova'],
#   'affiliation': ['State Budgetary Institution City Polyclinic #180, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['V A', 'VA', 'Metelskaya'],
#   'affiliation': ['National Medical Research Center for Preventive Medicine of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['I Y', 'IY', 'Koltunov'],
#   'affiliation': ['RUDN University, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['V P', 'VP', 'Voronina'],
#   'affiliation': ['National Medical Research Center for Preventive Medicine of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['A P', 'AP', 'Mazaev'],
#   'affiliation': ["Morozov Children's City Clinical Hospital, Moscow, Russia."],
#   'pmid': '32345202'},
#  {'author': ['A A', 'AA', 'Arutyunov'],
#   'affiliation': ['National Medical Research Center for Cardiology of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['V A', 'VA', 'Vygodin'],
#   'affiliation': ['National Medical Research Center for Preventive Medicine of the Ministry of Healthcare, Moscow, Russia.'],
#   'pmid': '32345202'},
#  {'author': ['Ming-Chao', 'MC', 'He'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Zhe', 'Z', 'Shi'],
#   'affiliation': ['Shanghai Key Laboratory of Psychotic Disorders, Shanghai Mental Health Center, Shanghai Jiao Tong University School of Medicine, Shanghai 201108, P. R. China.',
#    'Division of Stem Cell Regulation and Application, Key Laboratory for Quality Evaluation of Bulk Herbs of Hunan Province, Hunan University of Chinese Medicine, Changsha 410208, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Meng', 'M', 'Qin'],
#   'affiliation': ['College of Life Science and Technology, Beijing University of Chemical Technology, Beijing 100029, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Nan-Nan', 'NN', 'Sha'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Yue', 'Y', 'Li'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Duan-Fang', 'DF', 'Liao'],
#   'affiliation': ['Division of Stem Cell Regulation and Application, Key Laboratory for Quality Evaluation of Bulk Herbs of Hunan Province, Hunan University of Chinese Medicine, Changsha 410208, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Fu-Hui', 'FH', 'Lin'],
#   'affiliation': ['Department of Orthopaedic, Shenzhen Pingle Orthopaedic Hospital, Shenzhen 518000, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Bing', 'B', 'Shu'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Yue-Li', 'YL', 'Sun'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Ti-Fei', 'TF', 'Yuan'],
#   'affiliation': ['Shanghai Key Laboratory of Psychotic Disorders, Shanghai Mental Health Center, Shanghai Jiao Tong University School of Medicine, Shanghai 201108, P. R. China.',
#    'Co-innovation Center of Neuroregeneration, Nantong University, Nantong 226001, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Yong-Jun', 'YJ', 'Wang'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Yan', 'Y', 'Zhang'],
#   'affiliation': ['Spine Disease Research Institute, Longhua Hospital, Shanghai University of Traditional Chinese Medicine, Shanghai 200032, P. R. China.',
#    'Key Laboratory of Theory and Therapy of Muscles and Bones, Ministry of Education, Shanghai 200032, P. R. China.'],
#   'pmid': '32345030'},
#  {'author': ['Anna', 'A', 'Stippl'],
#   'affiliation': ['Department of Psychiatry and Psychotherapy, Charité, University Medicine Berlin, Campus Benjamin Franklin, Berlin, Germany.'],
#   'pmid': '32344410'},
#  {'author': ['Fatma Nur', 'FN', 'Kirkgöze'],
#   'affiliation': ['Department of Psychiatry and Psychotherapy, Charité, University Medicine Berlin, Campus Benjamin Franklin, Berlin, Germany.'],
#   'pmid': '32344410'},
#  {'author': ['Malek', 'M', 'Bajbouj'],
#   'affiliation': ['Department of Psychiatry and Psychotherapy, Charité, University Medicine Berlin, Campus Benjamin Franklin, Berlin, Germany.'],
#   'pmid': '32344410'},
#  {'author': ['Simone', 'S', 'Grimm'],
#   'affiliation': ['Department of Psychiatry and Psychotherapy, Charité, University Medicine Berlin, Campus Benjamin Franklin, Berlin, Germany, simone.grimm@charite.de.',
#    'MSB Medical School Berlin, Berlin, Germany, simone.grimm@charite.de.',
#    'Department of Psychiatry, Psychotherapy and Psychosomatics, University of Zurich, Psychiatric Hospital, Zurich, Switzerland, simone.grimm@charite.de.'],
#   'pmid': '32344410'},
#  {'author': ['Chaoliang', 'C', 'Tang'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Yida', 'Y', 'Hu'],
#   'affiliation': ['Department of Anesthesiology, Renmin Hospital of Wuhan University, Wuhan, Hubei 430060, China.'],
#   'pmid': '32343308'},
#  {'author': ['Zhetao', 'Z', 'Zhang'],
#   'affiliation': ['Department of Pharmacy, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Zeyuan', 'Z', 'Wei'],
#   'affiliation': ['Department of Pharmacy, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Hongtao', 'H', 'Wang'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Qingtian', 'Q', 'Geng'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Si', 'S', 'Shi'],
#   'affiliation': ['Department of Anesthesiology, Renmin Hospital of Wuhan University, Wuhan, Hubei 430060, China.'],
#   'pmid': '32343308'},
#  {'author': ['Song', 'S', 'Wang'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Jiawu', 'J', 'Wang'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Xiaoqing', 'X', 'Chai'],
#   'affiliation': ['Department of Anesthesiology, The First Affiliated Hospital of USTC, Division of Life Sciences and Medicine, University of Science and Technology of China, Hefei, Anhui 230001, China.'],
#   'pmid': '32343308'},
#  {'author': ['Matthew R', 'MR', 'Carazo'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA.",
#    "Department of Medicine Brigham and Women's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.'],
#   'pmid': '32342722'},
#  {'author': ['Meghan S', 'MS', 'Kolodziej'],
#   'affiliation': ["Department of Psychiatry Brigham and Women's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.'],
#   'pmid': '32342722'},
#  {'author': ['Elizabeth S', 'ES', 'DeWitt'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA."],
#   'pmid': '32342722'},
#  {'author': ['Nadine A', 'NA', 'Kasparian'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.',
#    "Discipline of Paediatrics School of Women's and Children's Health The University of New South Wales Sydney NSW Australia."],
#   'pmid': '32342722'},
#  {'author': ['Jane W', 'JW', 'Newburger'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA."],
#   'pmid': '32342722'},
#  {'author': ['Valeria E', 'VE', 'Duarte'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA.",
#    "Department of Medicine Brigham and Women's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.'],
#   'pmid': '32342722'},
#  {'author': ['Michael N', 'MN', 'Singh'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA.",
#    "Department of Medicine Brigham and Women's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.'],
#   'pmid': '32342722'},
#  {'author': ['Alexander R', 'AR', 'Opotowsky'],
#   'affiliation': ["Department of Cardiology Boston Children's Hospital Boston MA.",
#    "Department of Medicine Brigham and Women's Hospital Boston MA.",
#    'Harvard Medical School Boston MA.'],
#   'pmid': '32342722'},
#  {'author': ['Justyna', 'J', 'Godos'],
#   'affiliation': ['Oasi Research Institute-IRCCS, 94018 Troina, Italy.'],
#   'pmid': '32340112'},
# ...
#   'pmid': '32172519'},
#  {'author': ['Yong', 'Y', 'Chen'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Rong-Jia', 'RJ', 'Wu'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Shi-Feng', 'SF', 'Guan'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Yun-Yun', 'YY', 'Pan'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Qian-Bo', 'QB', 'Wang'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Dan', 'D', 'Tang'],
#   'affiliation': ["Guangdong Provincial Key Laboratory of Pharmacodynamic Constituents of TCM and New Drugs Research, College of Pharmacy, Jinan University, Guangzhou, 510632, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Tao', 'T', 'Zhu'],
#   'affiliation': ["Guangdong Provincial Key Laboratory of Pharmacodynamic Constituents of TCM and New Drugs Research, College of Pharmacy, Jinan University, Guangzhou, 510632, People's Republic of China."],
#   'pmid': '32172519'},
#  {'author': ['Ji-Sheng', 'JS', 'Chen'],
#   'affiliation': ["Pharmaceutical Department of The First Affiliated Hospital of Guangdong Pharmaceutical University, Clinical Pharmacy Department of Guangdong Pharmaceutical University, Guangzhou, 510080, People's Republic of China. cjslym@163.com."],
#   'pmid': '32172519'},
#  {'author': ['Akbar Hajizadeh', 'AH', 'Moghaddam'],
#   'affiliation': ['Department of Biology, Faculty of Basic Sciences, University of Mazandaran, Babolsar, Iran. Electronic address: a.hajizadeh@umz.ac.ir.'],
#   'pmid': '32171791'},
#  {'author': ['Seyed Reza', 'SR', 'Mokhtari Sangdehi'],
#   'affiliation': ['Department of Biology, Faculty of Basic Sciences, University of Mazandaran, Babolsar, Iran. Electronic address: reza.mokhtari1100@gmail.com.'],
#   'pmid': '32171791'},
#  {'author': ['Mojtaba', 'M', 'Ranjbar'],
#   'affiliation': ['Faculty of Biotechnology, Amol University of Special Modern Technologies, Amol, Iran. Electronic address: ranjbarmf@gmail.com.'],
#   'pmid': '32171791'},
#  {'author': ['Vahid', 'V', 'Hasantabar'],
#   'affiliation': ['Department of Organic Polymer Chemistry, Faculty of Chemistry, University of Mazandaran, Babolsar, Iran. Electronic address: vahidhasantabar@yahoo.com.'],
#   'pmid': '32171791'},
#  {'author': ['Carla', 'C', 'Ramon-Duaso'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain; Department of Experimental and Health Sciences, Pompeu Fabra University (CEXS-UPF), Barcelona, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Jose', 'J', 'Rodríguez-Morató'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain; Department of Experimental and Health Sciences, Pompeu Fabra University (CEXS-UPF), Barcelona, Spain; CIBER de la Fisiopatología de la Obesidad y la Nutrición (CIBERON), Instituto de Salud Carlos III, Madrid, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Estela', 'E', 'Selma-Soriano'],
#   'affiliation': ['Translational Genomics Group, Incliva Health Research Institute, Valencia, Spain; Interdisciplinary Research Structure for Biotechnology and Biomedicine (ERI BIOTECMED), University of Valencia, Valencia, Spain; CIPF-INCLIVA Joint Unit, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Cristina', 'C', 'Fernández-Avilés'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Rubén', 'R', 'Artero'],
#   'affiliation': ['Translational Genomics Group, Incliva Health Research Institute, Valencia, Spain; Interdisciplinary Research Structure for Biotechnology and Biomedicine (ERI BIOTECMED), University of Valencia, Valencia, Spain; CIPF-INCLIVA Joint Unit, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Rafael', 'R', 'de la Torre'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain; Department of Experimental and Health Sciences, Pompeu Fabra University (CEXS-UPF), Barcelona, Spain; CIBER de la Fisiopatología de la Obesidad y la Nutrición (CIBERON), Instituto de Salud Carlos III, Madrid, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Óscar J', 'ÓJ', 'Pozo'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain.'],
#   'pmid': '32171677'},
#  {'author': ['Patricia', 'P', 'Robledo'],
#   'affiliation': ['Integrative Pharmacology and Systems Neuroscience, IMIM-Hospital del Mar Medical Research Institute, Barcelona, Spain; Department of Experimental and Health Sciences, Pompeu Fabra University (CEXS-UPF), Barcelona, Spain. Electronic address: probledo@imim.es.'],
#   'pmid': '32171677'},
#  {'author': ['Maria G', 'MG', 'Alessi'],
#   'affiliation': ['Health Psychology PhD Program, UNC Charlotte, Charlotte, North Carolina, USA.'],
#   'pmid': '32171052'},
#  {'author': ['Jeanette M', 'JM', 'Bennett'],
#   'affiliation': ['Health Psychology PhD Program, UNC Charlotte, Charlotte, North Carolina, USA.',
#    'Department of Psychological Science, UNC Charlotte, Charlotte, North Carolina, USA.'],
#   'pmid': '32171052'},
#  {'author': ['Chunling', 'C', 'Yuan'],
#   'affiliation': ["Department of Medicinal Chemistry, Pharmacy School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China. yutong8747@163.com."],
#   'pmid': '32170675'},
#  {'author': ['Chunmei', 'C', 'Dai'],
#   'affiliation': ["Department of Pharmaceutical Administration, Pharmacy School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China."],
#   'pmid': '32170675'},
#  {'author': ['Ziqiang', 'Z', 'Li'],
#   'affiliation': ["Department of Medicinal Chemistry, Pharmacy School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China."],
#   'pmid': '32170675'},
#  {'author': ['Li', 'L', 'Zheng'],
#   'affiliation': ["Department of Pharmaceutical Analysis, Pharmacy School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China."],
#   'pmid': '32170675'},
#  {'author': ['Miaoxin', 'M', 'Zhao'],
#   'affiliation': ["Graduate School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China."],
#   'pmid': '32170675'},
#  {'author': ['Sumin', 'S', 'Dong'],
#   'affiliation': ["Graduate School, Jinzhou Medical University, Jinzhou, 121001, People's Republic of China."],
#   'pmid': '32170675'},
#  {'author': ['Yinfeng', 'Y', 'Dong'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China. Electronic address: dongyf@njucm.edu.cn.'],
#   'pmid': '32165183'},
#  {'author': ['Xuyang', 'X', 'Wang'],
#   'affiliation': ["Department of Neurosurgery, Shanghai Jiao Tong University Affiliated 6th People's Hospital, Shanghai 200233, China."],
#   'pmid': '32165183'},
#  {'author': ['Yan', 'Y', 'Zhou'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Qiaomu', 'Q', 'Zheng'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Zheng', 'Z', 'Chen'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Hua', 'H', 'Zhang'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Zhiling', 'Z', 'Sun'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Guihua', 'G', 'Xu'],
#   'affiliation': ['Department of Medical Care, School of Nursing, Nanjing University of Chinese Medicine, Nanjing 210023, China.'],
#   'pmid': '32165183'},
#  {'author': ['Gang', 'G', 'Hu'],
#   'affiliation': ['Department of Pharmacology, School of Medicine and Life Sciences, Nanjing University of Chinese Medicine, Nanjing 210023, China. Electronic address: ghu@njmu.edu.cn.'],
#   'pmid': '32165183'},
#  {'author': ['Jeon-Kyung', 'JK', 'Kim'],
#   'affiliation': ['Neurobiota Research Center, Department of Pharmacy, Kyung Hee University, Seoul, South Korea.',
#    'Department of Life and Nanopharmaceutical Sciences, Kyung Hee University, Seoul, South Korea.'],
#   'pmid': '32158447'},
#  {'author': ['Kyung-Eon', 'KE', 'Lee'],
#   'affiliation': ['Neurobiota Research Center, Department of Pharmacy, Kyung Hee University, Seoul, South Korea.',
#    'Department of Life and Nanopharmaceutical Sciences, Kyung Hee University, Seoul, South Korea.'],
#   'pmid': '32158447'},
#  {'author': ['Sang-Ah', 'SA', 'Lee'],
#   'affiliation': ['Neurobiota Research Center, Department of Pharmacy, Kyung Hee University, Seoul, South Korea.',
#    'Department of Life and Nanopharmaceutical Sciences, Kyung Hee University, Seoul, South Korea.'],
#   'pmid': '32158447'},
#  {'author': ['Hyo-Min', 'HM', 'Jang'],
#   'affiliation': ['Neurobiota Research Center, Department of Pharmacy, Kyung Hee University, Seoul, South Korea.',
#    'Department of Life and Nanopharmaceutical Sciences, Kyung Hee University, Seoul, South Korea.'],
#   'pmid': '32158447'},
#  {'author': ['Dong-Hyun', 'DH', 'Kim'],
#   'affiliation': ['Neurobiota Research Center, Department of Pharmacy, Kyung Hee University, Seoul, South Korea.',
#    'Department of Life and Nanopharmaceutical Sciences, Kyung Hee University, Seoul, South Korea.'],
#   'pmid': '32158447'},
#  {'author': ['Juan-Juan', 'JJ', 'Yang'],
#   'affiliation': ["Department of Health Management, the Second Affiliated Hospital of Xi'an Jiaotong University, Xi'an, 710004, Shaanxi Provice, China."],
#   'pmid': '32158005'},
#  {'author': ['Wei', 'W', 'Jiang'],
#   'affiliation': ["Department of Oncology, the Second Affiliated Hospital of Xi' an Jiaotong University, Xi'an, 710004, Shaanxi Provice, China. Electronic address: jiangweixjtu526@xjtu.edu.cn."],
#   'pmid': '32158005'},
#  {'author': ['L Parker', 'LP', 'Gregg'],
#   'affiliation': ['Division of Nephrology, Department of Medicine, University of Texas Southwestern Medical Center, Dallas, Texas, USA.',
#    'Division of Nephrology, Medical Service, Veterans Affairs North Texas Health Care System, Dallas, Texas, USA.'],
#   'pmid': '32154453'},
#  {'author': ['Thomas', 'T', 'Carmody'],
#   'affiliation': ['Department of Clinical Sciences, University of Texas Southwestern Medical Center, Dallas, Texas, USA.'],
#   'pmid': '32154453'},
#  {'author': ['Dustin', 'D', 'Le'],
#   'affiliation': ['Department of Medicine, University of Michigan, Ann Arbor, Michigan, USA.'],
#   'pmid': '32154453'},
#  {'author': ['Gerard', 'G', 'Martins'],
#   'affiliation': ['Division of Nephrology, Department of Medicine, University of Texas Southwestern Medical Center, Dallas, Texas, USA.'],
#   'pmid': '32154453'},
#  {'author': ['Madhukar', 'M', 'Trivedi'],
#   'affiliation': ['Department of Psychiatry, University of Texas Southwestern Medical Center, Dallas, Texas, USA.'],
#   'pmid': '32154453'},
#  {'author': ['S Susan', 'SS', 'Hedayati'],
#   'affiliation': ['Division of Nephrology, Department of Medicine, University of Texas Southwestern Medical Center, Dallas, Texas, USA.'],
#   'pmid': '32154453'},
#  {'author': ['Lukas', 'L', 'Lanser'],
#   'affiliation': ['Department of Internal Medicine II, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Patricia', 'P', 'Kink'],
#   'affiliation': ['Department of Internal Medicine II, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Eva Maria', 'EM', 'Egger'],
#   'affiliation': ['Department of Internal Medicine II, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Wolfgang', 'W', 'Willenbacher'],
#   'affiliation': ['Department of Internal Medicine V, Medical University of Innsbruck, Innsbruck, Austria.',
#    'Oncotyrol Centre for Personalized Cancer Medicine, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Dietmar', 'D', 'Fuchs'],
#   'affiliation': ['Division of Biological Chemistry, Biocenter, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Guenter', 'G', 'Weiss'],
#   'affiliation': ['Department of Internal Medicine II, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['Katharina', 'K', 'Kurz'],
#   'affiliation': ['Department of Internal Medicine II, Medical University of Innsbruck, Innsbruck, Austria.'],
#   'pmid': '32153576'},
#  {'author': ['David R', 'DR', 'Goldsmith'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University School of Medicine, Atlanta, GA, United States.'],
#   'pmid': '32153436'},
#  {'author': ['Mark Hyman', 'MH', 'Rapaport'],
#   'affiliation': ['Department of Psychiatry and Behavioral Sciences, Emory University School of Medicine, Atlanta, GA, United States.'],
#   'pmid': '32153436'},
#  {'author': ['M A', 'MA', 'Nettis'],
#   'affiliation': ["Institute of Psychiatry, Psychology and Neuroscience, King's College London, Department of Psychological Medicine, London, UK. maria.a.nettis@kcl.ac.uk.",
#    "National Institute for Health and Research Biomedical Research Centre at South London and Maudsley NHS Foundation Trust and King's College London, London, UK. maria.a.nettis@kcl.ac.uk."],
#   'pmid': '32152285'},
#  {'author': ['M', 'M', 'Veronese'],
#   'affiliation': ["National Institute for Health and Research Biomedical Research Centre at South London and Maudsley NHS Foundation Trust and King's College London, London, UK.",
#    "Institute of Psychiatry, Psychology and Neuroscience, King's College London Department of Neuroimaging, London, UK."],
#   'pmid': '32152285'},
#  {'author': ['N', 'N', 'Nikkheslat'],
#   'affiliation': ["Institute of Psychiatry, Psychology and Neuroscience, King's College London, Department of Psychological Medicine, London, UK."],
#   'pmid': '32152285'},
#  {'author': ['N', 'N', 'Mariani'],
#   'affiliation': ["Institute of Psychiatry, Psychology and Neuroscience, King's College London, Department of Psychological Medicine, London, UK."],
#   'pmid': '32152285'},
#  {'author': ['G', 'G', 'Lombardo'],
#   'affiliation': ["Institute of Psychiatry, Psychology and Neuroscience, King's College London, Department of Psychological Medicine, London, UK."],
#   'pmid': '32152285'},
#  {'author': ['L', 'L', 'Sforzini'],
#   'affiliation': ["Institute of Psychiatry, Psychology and Neuroscience, King's College London, Department of Psychological Medicine, London, UK.",
#    "Universita' degli Studi di Milano, Psychiatry Unit, Department of Biomedical and Clinical Sciences, Luigi Sacco Hospital, Milan, Italy."],
#   'pmid': '32152285'},
#  ...]

# %% [markdown]
# ## Create Tables

# %%
import itertools
#Create Author List
def create_author_affil_list(papers_result):
    authors = []
    for paper_dictionary in papers_result:
        for author, affil in itertools.product(paper_dictionary['author_list'], paper_dictionary['affil_list']):
            try:
                authors.append({'author_list' : author, 
                                'author_string' : author[2] + ", " + author[0],
                                'affiliation' : affil, 
                                'locations' : get_location(affil), 
                                'title' : paper_dictionary['title'],
                                'pmid' : paper_dictionary['pmid']
                                
                               })             
            except Exception as err:
                print(err)
                pass
    return authors

authors_affils = create_author_affil_list(papers_result)
authors_affils
# Out:
# [{'author_list': ['Annelise', 'A', 'Madison'],
#   'author_string': 'Madison, Annelise',
#   'affiliation': 'Institute for Behavioral Medicine Research, The Ohio State University College of Medicine, United States.',
#   'locations': ['United States'],
#   'title': 'Stress, depression, diet, and the gut microbiota: human-bacteria interactions at the core of psychoneuroimmunology and nutrition.',
#   'pmid': '32395568'},
#  {'author_list': ['Annelise', 'A', 'Madison'],
#   'author_string': 'Madison, Annelise',
#   'affiliation': 'Department of Psychiatry and Behavioral Health, The Ohio State University College of Medicine, United States.',
#   'locations': ['United States'],
#   'title': 'Stress, depression, diet, and the gut microbiota: human-bacteria interactions at the core of psychoneuroimmunology and nutrition.',
#   'pmid': '32395568'},
#  {'author_list': ['Janice K', 'JK', 'Kiecolt-Glaser'],
#   'author_string': 'Kiecolt-Glaser, Janice K',
#   'affiliation': 'Institute for Behavioral Medicine Research, The Ohio State University College of Medicine, United States.',
#   'locations': ['United States'],
#   'title': 'Stress, depression, diet, and the gut microbiota: human-bacteria interactions at the core of psychoneuroimmunology and nutrition.',
#   'pmid': '32395568'},
#  {'author_list': ['Janice K', 'JK', 'Kiecolt-Glaser'],
#   'author_string': 'Kiecolt-Glaser, Janice K',
#   'affiliation': 'Department of Psychiatry and Behavioral Health, The Ohio State University College of Medicine, United States.',
#   'locations': ['United States'],
#   'title': 'Stress, depression, diet, and the gut microbiota: human-bacteria interactions at the core of psychoneuroimmunology and nutrition.',
#   'pmid': '32395568'},
#  {'author_list': ['Craig', 'C', 'Friesen'],
#   'author_string': 'Friesen, Craig',
#   'affiliation': "Division of Developmental and Behavioral Sciences, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA.",
#   'locations': ['Kansas City'],
#   'title': 'A cross-sectional study of nausea in functional abdominal pain: relation to mucosal mast cells and psychological functioning.',
#   'pmid': '32393272'},
#  {'author_list': ['Meenal', 'M', 'Singh'],
#   'author_string': 'Singh, Meenal',
#   'affiliation': "Division of Developmental and Behavioral Sciences, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA.",
#   'locations': ['Kansas City'],
#   'title': 'A cross-sectional study of nausea in functional abdominal pain: relation to mucosal mast cells and psychological functioning.',
#   'pmid': '32393272'},
#  {'author_list': ['Vivekanand', 'V', 'Singh'],
#   'author_string': 'Singh, Vivekanand',
#   'affiliation': "Division of Developmental and Behavioral Sciences, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA.",
#   'locations': ['Kansas City'],
#   'title': 'A cross-sectional study of nausea in functional abdominal pain: relation to mucosal mast cells and psychological functioning.',
#   'pmid': '32393272'},
#  {'author_list': ['Jennifer V', 'JV', 'Schurman'],
#   'author_string': 'Schurman, Jennifer V',
#   'affiliation': "Division of Developmental and Behavioral Sciences, Children's Mercy Kansas City, 2401 Gillham Road, Kansas City, MO, 64108, USA.",
#   'locations': ['Kansas City'],
#   'title': 'A cross-sectional study of nausea in functional abdominal pain: relation to mucosal mast cells and psychological functioning.',
#   'pmid': '32393272'},
#  {'author_list': ['Owen M', 'OM', 'Vega'],
#   'author_string': 'Vega, Owen M',
#   'affiliation': 'Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#   'locations': ['Los Angeles'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Owen M', 'OM', 'Vega'],
#   'author_string': 'Vega, Owen M',
#   'affiliation': 'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.',
#   'locations': ['Mexico City', 'Mexico'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Shaheen', 'S', 'Abkenari'],
#   'author_string': 'Abkenari, Shaheen',
#   'affiliation': 'Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#   'locations': ['Los Angeles'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Shaheen', 'S', 'Abkenari'],
#   'author_string': 'Abkenari, Shaheen',
#   'affiliation': 'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.',
#   'locations': ['Mexico City', 'Mexico'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Zhen', 'Z', 'Tong'],
#   'author_string': 'Tong, Zhen',
#   'affiliation': 'Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#   'locations': ['Los Angeles'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Zhen', 'Z', 'Tong'],
#   'author_string': 'Tong, Zhen',
#   'affiliation': 'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.',
#   'locations': ['Mexico City', 'Mexico'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Austin', 'A', 'Tedman'],
#   'author_string': 'Tedman, Austin',
#   'affiliation': 'Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#   'locations': ['Los Angeles'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Austin', 'A', 'Tedman'],
#   'author_string': 'Tedman, Austin',
#   'affiliation': 'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.',
#   'locations': ['Mexico City', 'Mexico'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Sara', 'S', 'Huerta-Yepez'],
#   'author_string': 'Huerta-Yepez, Sara',
#   'affiliation': 'Pathology and Laboratory Medicine, University of California, Los Angeles, USA.',
#   'locations': ['Los Angeles'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Sara', 'S', 'Huerta-Yepez'],
#   'author_string': 'Huerta-Yepez, Sara',
#   'affiliation': 'Unidad de Investigación en Enfermedades Oncológicas, Hospital Infantil de Mexico, Federico Gomez, Mexico City, Mexico.',
#   'locations': ['Mexico City', 'Mexico'],
#   'title': 'Omega-3 Polyunsaturated Fatty Acids and Lung Cancer: nutrition or Pharmacology?',
#   'pmid': '32393071'},
#  {'author_list': ['Bonan', 'B', 'Liu'],
#   'author_string': 'Liu, Bonan',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bonan', 'B', 'Liu'],
#   'author_string': 'Liu, Bonan',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bonan', 'B', 'Liu'],
#   'author_string': 'Liu, Bonan',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiayuan', 'J', 'Kou'],
#   'author_string': 'Kou, Jiayuan',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiayuan', 'J', 'Kou'],
#   'author_string': 'Kou, Jiayuan',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiayuan', 'J', 'Kou'],
#   'author_string': 'Kou, Jiayuan',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Fuyan', 'F', 'Li'],
#   'author_string': 'Li, Fuyan',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Fuyan', 'F', 'Li'],
#   'author_string': 'Li, Fuyan',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Fuyan', 'F', 'Li'],
#   'author_string': 'Li, Fuyan',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Da', 'D', 'Huo'],
#   'author_string': 'Huo, Da',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Da', 'D', 'Huo'],
#   'author_string': 'Huo, Da',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Da', 'D', 'Huo'],
#   'author_string': 'Huo, Da',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiaran', 'J', 'Xu'],
#   'author_string': 'Xu, Jiaran',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiaran', 'J', 'Xu'],
#   'author_string': 'Xu, Jiaran',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Jiaran', 'J', 'Xu'],
#   'author_string': 'Xu, Jiaran',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xiaoxi', 'X', 'Zhou'],
#   'author_string': 'Zhou, Xiaoxi',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xiaoxi', 'X', 'Zhou'],
#   'author_string': 'Zhou, Xiaoxi',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xiaoxi', 'X', 'Zhou'],
#   'author_string': 'Zhou, Xiaoxi',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dehao', 'D', 'Meng'],
#   'author_string': 'Meng, Dehao',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dehao', 'D', 'Meng'],
#   'author_string': 'Meng, Dehao',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dehao', 'D', 'Meng'],
#   'author_string': 'Meng, Dehao',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Murtaza', 'M', 'Ghulam'],
#   'author_string': 'Ghulam, Murtaza',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Murtaza', 'M', 'Ghulam'],
#   'author_string': 'Ghulam, Murtaza',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Murtaza', 'M', 'Ghulam'],
#   'author_string': 'Ghulam, Murtaza',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bobkov', 'B', 'Artyom'],
#   'author_string': 'Artyom, Bobkov',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bobkov', 'B', 'Artyom'],
#   'author_string': 'Artyom, Bobkov',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bobkov', 'B', 'Artyom'],
#   'author_string': 'Artyom, Bobkov',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xu', 'X', 'Gao'],
#   'author_string': 'Gao, Xu',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xu', 'X', 'Gao'],
#   'author_string': 'Gao, Xu',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Xu', 'X', 'Gao'],
#   'author_string': 'Gao, Xu',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Ning', 'N', 'Ma'],
#   'author_string': 'Ma, Ning',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Ning', 'N', 'Ma'],
#   'author_string': 'Ma, Ning',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Ning', 'N', 'Ma'],
#   'author_string': 'Ma, Ning',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dong', 'D', 'Han'],
#   'author_string': 'Han, Dong',
#   'affiliation': 'Department of Biochemistry and Molecular Biology, Harbin Medical University, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dong', 'D', 'Han'],
#   'author_string': 'Han, Dong',
#   'affiliation': 'Basic Medical Institute of Heilongjiang Medical Science Academy, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Dong', 'D', 'Han'],
#   'author_string': 'Han, Dong',
#   'affiliation': 'Translational Medicine Center of Northern China, Harbin 150081, China.',
#   'locations': ['China', 'Harbin'],
#   'title': 'Lemon essential oil ameliorates age-associated cognitive dysfunction via modulating hippocampal synaptic density and inhibiting acetylcholinesterase.',
#   'pmid': '32392535'},
#  {'author_list': ['Bolu', 'B', 'Sun'],
#   'author_string': 'Sun, Bolu',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Dai', 'D', 'Li'],
#   'author_string': 'Li, Dai',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Xiaohui', 'X', 'Hou'],
#   'author_string': 'Hou, Xiaohui',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Wuyan', 'W', 'Li'],
#   'author_string': 'Li, Wuyan',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Yuqiang', 'Y', 'Gou'],
#   'author_string': 'Gou, Yuqiang',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Fangdi', 'F', 'Hu'],
#   'author_string': 'Hu, Fangdi',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Wen', 'W', 'Li'],
#   'author_string': 'Li, Wen',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['Xiaofeng', 'X', 'Shi'],
#   'author_string': 'Shi, Xiaofeng',
#   'affiliation': 'Gansu Academy of Medical Science, Xiaoxihu East Street, Lanzhou, Gansu Province 730050, China. Electronic address: shixiaofeng2005@sina.com.',
#   'locations': ['China', 'Lanzhou'],
#   'title': 'A novel electrochemical immunosensor for the highly sensitive and selective detection of the depression marker human apolipoprotein A4.',
#   'pmid': '32388438'},
#  {'author_list': ['David R', 'DR', 'Goldsmith'],
#   'author_string': 'Goldsmith, David R',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Mandakh', 'M', 'Bekhbat'],
#   'author_string': 'Bekhbat, Mandakh',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Ngoc-Anh', 'NA', 'Le'],
#   'author_string': 'Le, Ngoc-Anh',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Xiangchuan', 'X', 'Chen'],
#   'author_string': 'Chen, Xiangchuan',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Bobbi J', 'BJ', 'Woolwine'],
#   'author_string': 'Woolwine, Bobbi J',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Zhihao', 'Z', 'Li'],
#   'author_string': 'Li, Zhihao',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Ebrahim', 'E', 'Haroon'],
#   'author_string': 'Haroon, Ebrahim',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Jennifer C', 'JC', 'Felger'],
#   'author_string': 'Felger, Jennifer C',
#   'affiliation': 'Department of Psychiatry and Behavioral Sciences, Emory University, Atlanta, GA 30322; The Winship Cancer Institute, Emory University, Atlanta, GA 30322. Electronic address: jfelger@emory.edu.',
#   'locations': ['Atlanta'],
#   'title': 'Protein and Gene Markers of Metabolic Dysfunction and Inflammation Together Associate with Functional Connectivity in Reward and Motor Circuits in Depression.',
#   'pmid': '32387344'},
#  {'author_list': ['Hai-Lian', 'HL', 'Yuan'],
#   'author_string': 'Yuan, Hai-Lian',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Yun-Li', 'YL', 'Zhao'],
#   'author_string': 'Zhao, Yun-Li',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Cai-Feng', 'CF', 'Ding'],
#   'author_string': 'Ding, Cai-Feng',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Pei-Feng', 'PF', 'Zhu'],
#   'author_string': 'Zhu, Pei-Feng',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Qiong', 'Q', 'Jin'],
#   'author_string': 'Jin, Qiong',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Ya-Ping', 'YP', 'Liu'],
#   'author_string': 'Liu, Ya-Ping',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Zhong-Tao', 'ZT', 'Ding'],
#   'author_string': 'Ding, Zhong-Tao',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Xiao-Dong', 'XD', 'Luo'],
#   'author_string': 'Luo, Xiao-Dong',
#   'affiliation': "Key Laboratory of Medicinal Chemistry for Natural Resource, Ministry of Education and Yunnan Province, School of Chemical Science and Technology, Yunnan University, Kunming 650091, People's Republic of China; State Laboratory of Phytochemistry and Plant Resources in West China, Kunming Institute of Botany, Chinese Academy of Sciences, Kunming, 650201, People's Republic of China. Electronic address: ztding@ynu.edu.cn.",
#   'locations': ['China', 'Kunming'],
#   'title': 'Anti-inflammatory and antinociceptive effects of Curcuma kwangsiensis and its bioactive terpenoids in vivo and in vitro.',
#   'pmid': '32387235'},
#  {'author_list': ['Norwin', 'N', 'Kubick'],
#   'author_string': 'Kubick, Norwin',
#   'affiliation': 'PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#   'locations': ['Sweden'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Norwin', 'N', 'Kubick'],
#   'author_string': 'Kubick, Norwin',
#   'affiliation': 'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.',
#   'locations': ['Poland'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Marta', 'M', 'Pajares'],
#   'author_string': 'Pajares, Marta',
#   'affiliation': 'PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#   'locations': ['Sweden'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Marta', 'M', 'Pajares'],
#   'author_string': 'Pajares, Marta',
#   'affiliation': 'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.',
#   'locations': ['Poland'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Ioana', 'I', 'Enache'],
#   'author_string': 'Enache, Ioana',
#   'affiliation': 'PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#   'locations': ['Sweden'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Ioana', 'I', 'Enache'],
#   'author_string': 'Enache, Ioana',
#   'affiliation': 'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.',
#   'locations': ['Poland'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Gina', 'G', 'Manda'],
#   'author_string': 'Manda, Gina',
#   'affiliation': 'PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#   'locations': ['Sweden'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Gina', 'G', 'Manda'],
#   'author_string': 'Manda, Gina',
#   'affiliation': 'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.',
#   'locations': ['Poland'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Michel-Edwar', 'ME', 'Mickael'],
#   'author_string': 'Mickael, Michel-Edwar',
#   'affiliation': 'PM forskningscentret, 17854 Ekerö Stockholm, Sweden.',
#   'locations': ['Sweden'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['Michel-Edwar', 'ME', 'Mickael'],
#   'author_string': 'Mickael, Michel-Edwar',
#   'affiliation': 'Neuroimmunology group, Department of experimental Genomics, Institute of Animal Breeding and Genetics, Polish Academy of Science, Postępu 36A, 05-552 Garbatka, Poland.',
#   'locations': ['Poland'],
#   'title': 'Repurposing Zileuton as a Depression Drug Using an AI and In Vitro Approach.',
#   'pmid': '32380663'},
#  {'author_list': ['I', 'I', 'Lewkowich'],
#   'author_string': 'Lewkowich, I',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['R', 'R', 'Ahlbrand'],
#   'author_string': 'Ahlbrand, R',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['E', 'E', 'Johnson'],
#   'author_string': 'Johnson, E',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['J', 'J', 'McAlees'],
#   'author_string': 'McAlees, J',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['N', 'N', 'Nawreen'],
#   'author_string': 'Nawreen, N',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['R', 'R', 'Raman'],
#   'author_string': 'Raman, R',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['I', 'I', 'Lingel'],
#   'author_string': 'Lingel, I',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['J', 'J', 'Hargis'],
#   'author_string': 'Hargis, J',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['C', 'C', 'Hoover'],
#   'author_string': 'Hoover, C',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['R', 'R', 'Sah'],
#   'author_string': 'Sah, R',
#   'affiliation': 'Dept. of Pharmacology & Systems Physiology, University of Cincinnati, Cincinnati OH, 45220; Neuroscience Graduate Program, University of Cincinnati, Cincinnati OH, 45220; VA Medical Center, Cincinnati, OH, 45220. Electronic address: sahr@uc.edu.',
#   'locations': ['Cincinnati'],
#   'title': 'Modulation of fear behavior and neuroimmune alterations in house dust mite exposed A/J mice, a model of severe asthma.',
#   'pmid': '32380274'},
#  {'author_list': ['Hartej', 'H', 'Gill'],
#   'author_string': 'Gill, Hartej',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Sabine', 'S', 'El-Halabi'],
#   'author_string': 'El-Halabi, Sabine',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Amna', 'A', 'Majeed'],
#   'author_string': 'Majeed, Amna',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Barjot', 'B', 'Gill'],
#   'author_string': 'Gill, Barjot',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Leanna M W', 'LMW', 'Lui'],
#   'author_string': 'Lui, Leanna M W',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Rodrigo B', 'RB', 'Mansur'],
#   'author_string': 'Mansur, Rodrigo B',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Orly', 'O', 'Lipsitz'],
#   'author_string': 'Lipsitz, Orly',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Nelson B', 'NB', 'Rodrigues'],
#   'author_string': 'Rodrigues, Nelson B',
#   'affiliation': 'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada; Department of Psychiatry, University of Toronto, Toronto, ON, Canada; Brain and Cognition Discovery Foundation, Toronto, ON, Canada.',
#   'locations': ['Toronto', 'Canada'],
#   'title': 'The Association Between Adverse Childhood Experiences and Inflammation in Patients with Major Depressive Disorder: A Systematic Review.',
#   'pmid': '32379599'},
#  {'author_list': ['Lee', 'L', 'Phan'],
# ...
#   'pmid': '32238816'},
#  {'author_list': ['Erica', 'E', 'Duncan'],
#   'author_string': 'Duncan, Erica',
#   'affiliation': 'Emory University School of Medicine, Department of Psychiatry and Behavioral Sciences, Atlanta, GA, USA.',
#   'locations': ['Atlanta'],
#   'title': 'Inflammatory markers are associated with psychomotor slowing in patients with schizophrenia compared to healthy controls.',
#   'pmid': '32238816'},
#  {'author_list': ['Erica', 'E', 'Duncan'],
#   'author_string': 'Duncan, Erica',
#   'affiliation': 'Atlanta Veterans Affairs Medical Center, Decatur, GA, USA.',
#   'locations': ['Decatur'],
#   'title': 'Inflammatory markers are associated with psychomotor slowing in patients with schizophrenia compared to healthy controls.',
#   'pmid': '32238816'},
#  {'author_list': ['Sarah', 'S', 'Nazzari'],
#   'author_string': 'Nazzari, Sarah',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['Pasco', 'P', 'Fearon'],
#   'author_string': 'Fearon, Pasco',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['Frances', 'F', 'Rice'],
#   'author_string': 'Rice, Frances',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['Francesca', 'F', 'Ciceri'],
#   'author_string': 'Ciceri, Francesca',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['Massimo', 'M', 'Molteni'],
#   'author_string': 'Molteni, Massimo',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['Alessandra', 'A', 'Frigerio'],
#   'author_string': 'Frigerio, Alessandra',
#   'affiliation': 'Scientific Institute, IRCCS Eugenio Medea, Child Psychopathology Unit, Bosisio Parini, Lecco, Italy.',
#   'locations': ['Italy', 'Lecco'],
#   'title': 'Neuroendocrine and immune markers of maternal stress during pregnancy and infant cognitive development.',
#   'pmid': '32232990'},
#  {'author_list': ['David M', 'DM', 'Klyne'],
#   'author_string': 'Klyne, David M',
#   'affiliation': 'The University of Queensland, NHMRC Centre of Clinical Research Excellence in Spinal Pain, Injury and Health, School of Health and Rehabilitation Sciences, Brisbane, Australia.',
#   'locations': ['Brisbane', 'Australia'],
#   'title': 'Circulating Adipokines in Predicting the Transition from Acute to Persistent Low Back Pain.',
#   'pmid': '32232467'},
#  {'author_list': ['Paul W', 'PW', 'Hodges'],
#   'author_string': 'Hodges, Paul W',
#   'affiliation': 'The University of Queensland, NHMRC Centre of Clinical Research Excellence in Spinal Pain, Injury and Health, School of Health and Rehabilitation Sciences, Brisbane, Australia.',
#   'locations': ['Brisbane', 'Australia'],
#   'title': 'Circulating Adipokines in Predicting the Transition from Acute to Persistent Low Back Pain.',
#   'pmid': '32232467'},
#  {'author_list': ['Pia', 'P', 'Lopez-Jornet'],
#   'author_string': 'Lopez-Jornet, Pia',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Candela Castillo', 'CC', 'Felipe'],
#   'author_string': 'Felipe, Candela Castillo',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Luis', 'L', 'Pardo-Marin'],
#   'author_string': 'Pardo-Marin, Luis',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Jose J', 'JJ', 'Ceron'],
#   'author_string': 'Ceron, Jose J',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Eduardo', 'E', 'Pons-Fuster'],
#   'author_string': 'Pons-Fuster, Eduardo',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Asta', 'A', 'Tvarijonaviciute'],
#   'author_string': 'Tvarijonaviciute, Asta',
#   'affiliation': "Interdisciplinary Laboratory of Clinical Analysis, Interlab-UMU, Regional Campus of International Excellence 'Campus Mare Nostrum', University of Murcia, Espinardo, 30100 Murcia, Spain.",
#   'locations': ['Murcia', 'Spain'],
#   'title': 'Salivary Biomarkers and Their Correlation with Pain and Stress in Patients with Burning Mouth Syndrome.',
#   'pmid': '32231113'},
#  {'author_list': ['Ingrid', 'I', 'Tonhajzerova'],
#   'author_string': 'Tonhajzerova, Ingrid',
#   'affiliation': 'Department of Physiology, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Ingrid', 'I', 'Tonhajzerova'],
#   'author_string': 'Tonhajzerova, Ingrid',
#   'affiliation': 'Biomedical Center Martin, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Nikola', 'N', 'Sekaninova'],
#   'author_string': 'Sekaninova, Nikola',
#   'affiliation': 'Department of Physiology, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Nikola', 'N', 'Sekaninova'],
#   'author_string': 'Sekaninova, Nikola',
#   'affiliation': 'Biomedical Center Martin, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Lucia', 'L', 'Bona Olexova'],
#   'author_string': 'Bona Olexova, Lucia',
#   'affiliation': 'Department of Physiology, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Lucia', 'L', 'Bona Olexova'],
#   'author_string': 'Bona Olexova, Lucia',
#   'affiliation': 'Biomedical Center Martin, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Zuzana', 'Z', 'Visnovcova'],
#   'author_string': 'Visnovcova, Zuzana',
#   'affiliation': 'Department of Physiology, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Zuzana', 'Z', 'Visnovcova'],
#   'author_string': 'Visnovcova, Zuzana',
#   'affiliation': 'Biomedical Center Martin, Jessenius Faculty of Medicine in Martin, Comenius University in Bratislava, 03601 Martin, Slovakia.',
#   'locations': ['Bratislava', 'Slovakia', 'Martin'],
#   'title': 'Novel Insight into Neuroimmune Regulatory Mechanisms and Biomarkers Linking Major Depression and Vascular Diseases: The Dilemma Continues.',
#   'pmid': '32230840'},
#  {'author_list': ['Bianca A', 'BA', 'Lever-van Milligen'],
#   'author_string': 'Lever-van Milligen, Bianca A',
#   'affiliation': 'Amsterdam UMC, Vrije Universiteit Amsterdam, Department of Psychiatry and GGZ inGeest, Amsterdam Public Health Research Institute, the Netherlands.',
#   'locations': ['Netherlands', 'Amsterdam'],
#   'title': 'Physiological stress markers, mental health and objective physical function.',
#   'pmid': '32229341'},
#  {'author_list': ['Femke', 'F', 'Lamers'],
#   'author_string': 'Lamers, Femke',
#   'affiliation': 'Amsterdam UMC, Vrije Universiteit Amsterdam, Department of Psychiatry and GGZ inGeest, Amsterdam Public Health Research Institute, the Netherlands.',
#   'locations': ['Netherlands', 'Amsterdam'],
#   'title': 'Physiological stress markers, mental health and objective physical function.',
#   'pmid': '32229341'},
#  {'author_list': ['Johannes H', 'JH', 'Smit'],
#   'author_string': 'Smit, Johannes H',
#   'affiliation': 'Amsterdam UMC, Vrije Universiteit Amsterdam, Department of Psychiatry and GGZ inGeest, Amsterdam Public Health Research Institute, the Netherlands.',
#   'locations': ['Netherlands', 'Amsterdam'],
#   'title': 'Physiological stress markers, mental health and objective physical function.',
#   'pmid': '32229341'},
#  {'author_list': ['Brenda W J H', 'BWJH', 'Penninx'],
#   'author_string': 'Penninx, Brenda W J H',
#   'affiliation': 'Amsterdam UMC, Vrije Universiteit Amsterdam, Department of Psychiatry and GGZ inGeest, Amsterdam Public Health Research Institute, the Netherlands.',
#   'locations': ['Netherlands', 'Amsterdam'],
#   'title': 'Physiological stress markers, mental health and objective physical function.',
#   'pmid': '32229341'},
#  {'author_list': ['Richard T', 'RT', 'Liu'],
#   'author_string': 'Liu, Richard T',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Aislinn D', 'AD', 'Rowan-Nash'],
#   'author_string': 'Rowan-Nash, Aislinn D',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Ana E', 'AE', 'Sheehan'],
#   'author_string': 'Sheehan, Ana E',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Rachel F L', 'RFL', 'Walsh'],
#   'author_string': 'Walsh, Rachel F L',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Christina M', 'CM', 'Sanzari'],
#   'author_string': 'Sanzari, Christina M',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Benjamin J', 'BJ', 'Korry'],
#   'author_string': 'Korry, Benjamin J',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Peter', 'P', 'Belenky'],
#   'author_string': 'Belenky, Peter',
#   'affiliation': 'Department of Molecular Microbiology and Immunology, Brown University, Providence, RI, USA.',
#   'locations': ['Providence'],
#   'title': 'Reductions in anti-inflammatory gut bacteria are associated with depression in a sample of young adults.',
#   'pmid': '32229219'},
#  {'author_list': ['Jacob J', 'JJ', 'Rozich'],
#   'author_string': 'Rozich, Jacob J',
#   'affiliation': 'Division of Gastroenterology, University of California San Diego, La Jolla, California, USA.',
#   'locations': ['La Jolla'],
#   'title': 'Effect of Lifestyle Factors on Outcomes in Patients With Inflammatory Bowel Diseases.',
#   'pmid': '32224703'},
#  {'author_list': ['Jacob J', 'JJ', 'Rozich'],
#   'author_string': 'Rozich, Jacob J',
#   'affiliation': 'Division of Biomedical Informatics, Department of Medicine, University of California San Diego, La Jolla, California, USA.',
#   'locations': ['La Jolla'],
#   'title': 'Effect of Lifestyle Factors on Outcomes in Patients With Inflammatory Bowel Diseases.',
#   'pmid': '32224703'},
#  {'author_list': ['Ariela', 'A', 'Holmer'],
#   'author_string': 'Holmer, Ariela',
#   'affiliation': 'Division of Gastroenterology, University of California San Diego, La Jolla, California, USA.',
#   'locations': ['La Jolla'],
#   'title': 'Effect of Lifestyle Factors on Outcomes in Patients With Inflammatory Bowel Diseases.',
#   'pmid': '32224703'},
#  ...]

# %%
#Create Affiliations List
def create_affil_list(affiliations_result):
    affiliations = []
    for affiliation in affiliations_result:
        try:
            author_string = affiliation['author'][2] + ', ' + affiliation['author'][0]
            affiliations.append({'author' : str(author_string), 
                                 'affiliation' : affiliation['affiliation'], 
                                 'locations' : get_locations(affiliation['affiliation']), 
                                 'pmid' : affiliation['pmid']})
        except:
            print(affiliation)
            pass
    return affiliations

affiliations = create_affil_list(affiliations_result)

# %%
def filter_affiliations_by_location(affiliations_by_author, locations_of_interest = loi):
    """
    Given a list of author's affiliations and the user's locations of interest, filter the affiliations
    to only contain locations the user is interested in.
    
    Args:
        affiliations_by_author - 
        locations_of_interest - List: Hardcoded list of interesting locations
    Returns:
        
    """
    keep_affiliations_by_author = []
    for author in affiliations_by_author:
        for affiliation in [d['affiliation'] for d in author['affiliations']]:
            for location in locations_of_interest:
                if location.lower() in affiliation.lower():
                    keep_affiliations_by_author.append(author)
                    
    return keep_affiliations_by_author

def map_author_to_affil(authors_affils, locations_of_interest = loi):
    """
    Get `n` most common authors, find their top 3 affiliations and their geographic locations. 
    
    Filter list of authors by whether one of their affiliation locations lands in a location_of_interest
    
    Args:
    
    Returns:
        List - List elements are dictionaries containing data on an author's top 3 affiliations 
            if they land in the supplied `locations_of_interest`. 
    """
    author_affil_df = pd.DataFrame(authors_affils)
    top_authors = dict(Counter(author_affil_df['author_string']).most_common(200))
    #Get Affiliations for Top 200 Authors
    affiliations_by_author = []
    ### Count up most common authors
    author_list = list(top_authors.keys())
    
    for author_name in author_list[:5]:
        matching_affiliations = []
        
        matching_affiliations = [paper_author_affil.get('locations') for paper_author_affil in authors_affils \
                                 if paper_author_affil.get('locations') and paper_author_affil.get('author_string') == author_name]
        matching_affiliations = [item for sublist in matching_affiliations for item in sublist]
        """
        for entry in affiliations:
            if author_name == entry['author']:
                if entry.get('locations'):
                    for location in entry['locations']:
                        matching_affiliations.append(location)
                else:
                    matching_affiliations.append('none')
        """
        affs = Counter(matching_affiliations)
        
        reformatted_affs = []
        for aff in affs.most_common(3):
            reformatted_affs.append({'affiliation' : aff[0], 'count' : aff[1]})
        print(reformatted_affs)
        affiliations_by_author.append({'author' : author_name, 
                                       'total_papers' : sum(list(affs.values())),
                                       'affiliations' : reformatted_affs})

    #Filter authors down to authors matching locations of interest
    #keep_affiliations_by_author = filter_affiliations_by_location(affiliations_by_author, locations_of_interest = loi)
                
    return affiliations_by_author, top_authors

affiliations_by_author, top_authors = map_author_to_affil(authors_affils)
# Out:
# [{'affiliation': 'Australia', 'count': 33}, {'affiliation': 'Thailand', 'count': 27}, {'affiliation': 'Geelong', 'count': 27}]
# [{'affiliation': 'Australia', 'count': 43}, {'affiliation': 'Geelong', 'count': 20}, {'affiliation': 'Melbourne', 'count': 20}]
# [{'affiliation': 'Toronto', 'count': 24}, {'affiliation': 'Canada', 'count': 24}, {'affiliation': 'Ontario', 'count': 6}]
# [{'affiliation': 'Australia', 'count': 14}, {'affiliation': 'Geelong', 'count': 10}, {'affiliation': 'Thailand', 'count': 9}]
# [{'affiliation': 'Geelong', 'count': 8}, {'affiliation': 'Australia', 'count': 8}, {'affiliation': 'Brazil', 'count': 8}]

# %%
affiliations_by_author
# Out:
# [{'author': 'Maes, Michael',
#   'total_papers': 219,
#   'affiliations': [{'affiliation': 'Australia', 'count': 33},
#    {'affiliation': 'Thailand', 'count': 27},
#    {'affiliation': 'Geelong', 'count': 27}]},
#  {'author': 'Berk, Michael',
#   'total_papers': 137,
#   'affiliations': [{'affiliation': 'Australia', 'count': 43},
#    {'affiliation': 'Geelong', 'count': 20},
#    {'affiliation': 'Melbourne', 'count': 20}]},
#  {'author': 'McIntyre, Roger S',
#   'total_papers': 67,
#   'affiliations': [{'affiliation': 'Toronto', 'count': 24},
#    {'affiliation': 'Canada', 'count': 24},
#    {'affiliation': 'Ontario', 'count': 6}]},
#  {'author': 'Kanchanatawan, Buranee',
#   'total_papers': 80,
#   'affiliations': [{'affiliation': 'Australia', 'count': 14},
#    {'affiliation': 'Geelong', 'count': 10},
#    {'affiliation': 'Thailand', 'count': 9}]},
#  {'author': 'Carvalho, André F',
#   'total_papers': 68,
#   'affiliations': [{'affiliation': 'Geelong', 'count': 8},
#    {'affiliation': 'Australia', 'count': 8},
#    {'affiliation': 'Brazil', 'count': 8}]}]

# %%
sorted(affiliations_by_author, key=lambda k: k['total_papers'], reverse=True)
# Out:
# [{'author': 'Maes, Michael',
#   'total_papers': 219,
#   'affiliations': [{'affiliation': 'Australia', 'count': 33},
#    {'affiliation': 'Thailand', 'count': 27},
#    {'affiliation': 'Geelong', 'count': 27}]},
#  {'author': 'Berk, Michael',
#   'total_papers': 137,
#   'affiliations': [{'affiliation': 'Australia', 'count': 43},
#    {'affiliation': 'Geelong', 'count': 20},
#    {'affiliation': 'Melbourne', 'count': 20}]},
#  {'author': 'Kanchanatawan, Buranee',
#   'total_papers': 80,
#   'affiliations': [{'affiliation': 'Australia', 'count': 14},
#    {'affiliation': 'Geelong', 'count': 10},
#    {'affiliation': 'Thailand', 'count': 9}]},
#  {'author': 'Carvalho, André F',
#   'total_papers': 68,
#   'affiliations': [{'affiliation': 'Geelong', 'count': 8},
#    {'affiliation': 'Australia', 'count': 8},
#    {'affiliation': 'Brazil', 'count': 8}]},
#  {'author': 'McIntyre, Roger S',
#   'total_papers': 67,
#   'affiliations': [{'affiliation': 'Toronto', 'count': 24},
#    {'affiliation': 'Canada', 'count': 24},
#    {'affiliation': 'Ontario', 'count': 6}]}]

# %%
def author_affil_total_df(affiliations_by_author, n=25):
    """
    Combines data from previous steps to generate a dataframe of top publishing authors and their most frequently
    cited affiliations.
    """
    #Get top 25 from remaining authors
    affiliations_by_author_df = pd.DataFrame(affiliations_by_author)

    ### affiliations_by_author_df['totalPapers'] = affiliations_by_author_df['author'].map(top_authors)
    ### Removed because occasionally totalPapers was < sum of counts of topAffiliations which seems like a no-no
    ### `total_papers` is calculated in the `map_author_to_affil()` function and is calculated before 
    ### undesirable locations are filtered out
    affiliations_by_author_df['totalPapers'] = affiliations_by_author_df['total_papers']

    paper_counts_affiliations = affiliations_by_author_df.to_dict('records')

    flat_dict = []
    for author in paper_counts_affiliations:
        topAffiliations = []
        topAffiliations = {affiliation['affiliation'] : str(affiliation['count']) for affiliation in \
                           author['affiliations']}
        
        flat_dict.append({'author' : author['author'],
                          'topAffiliations' : topAffiliations,
                          'totalPapers' : author['totalPapers']})

    out_df = pd.DataFrame(flat_dict).sort_values(by='totalPapers', ascending=False).reset_index(drop=True)
    return out_df.head(n)
    
author_affil_total_df(affiliations_by_author)
# Out:
#                    author                                    topAffiliations  \
# 0           Maes, Michael  {'Australia': '33', 'Thailand': '27', 'Geelong...
# 1           Berk, Michael  {'Australia': '43', 'Geelong': '20', 'Melbourn...
# 2  Kanchanatawan, Buranee  {'Australia': '14', 'Geelong': '10', 'Thailand...
# 3       Carvalho, André F  {'Geelong': '8', 'Australia': '8', 'Brazil': '8'}
# 4       McIntyre, Roger S  {'Toronto': '24', 'Canada': '24', 'Ontario': '6'}
#
#    totalPapers
# 0          219
# 1          137
# 2           80
# 3           68
# 4           67

# %%
def get_authors_papers(author_of_interest, authors, papers_result):
    matching_pmids = []
    ### Find an authors PMIDs
    for author in authors:
        if author['author_string'] == author_of_interest:
            matching_pmids.append(author['pmid'])
    
    matching_papers = []
    for paper in papers_result:
        if paper['pmid'] in matching_pmids:
            matching_papers.append(paper)

    papers_sample = pd.DataFrame(matching_papers).to_dict('records')
    matching_papers_df = pd.DataFrame(matching_papers)
    matchedPapers = matching_papers_df.drop(columns=['pub_type_list', 'journal_info_list', 'author_list', 'keywords'])
    matchedPapers_dicts = matchedPapers.to_dict('records')
    
        
    return matchedPapers_dicts

#Get papers for top 25 authors
paper_top_author_list = []
for author_of_interest in top_authors:
    matchedPapers_dicts = get_authors_papers(author_of_interest, authors, papers_result)
    for matchedPaper in matchedPapers_dicts:
        top_paper = {'author' : author_of_interest, 
                     'title' : matchedPaper['title'], 
                     'pubdate' : matchedPaper['pubdate'], 
                     'link' : matchedPaper['link'], 
                     'pmid' : matchedPaper['pmid']}
        paper_top_author_list.append(top_paper)

paper_top_author_df = pd.DataFrame(paper_top_author_list)

affiliations_df = pd.DataFrame(affiliations)[['author', 'affiliation', 'pmid']]

big_df = pd.merge(paper_top_author_df, affiliations_df, on = ['author', 'pmid'])
out_dict = {}
for author_dict in affiliations_by_author:
    out_dict[author_dict['author']] = {'author' : author_dict['author'], 
                         'total_count' : author_dict['total_papers'],
                         'locations' : str([d['affiliation'] for d in author_dict['affiliations']]),
                           'paper_data' : big_df.loc[big_df['author'] == author_dict['author'], :].to_dict('records')
                       }
    
    
out_dict
# Out:
# {'Maes, Michael': {'author': 'Maes, Michael',
#   'total_count': 219,
#   'locations': "['Australia', 'Thailand', 'Geelong']",
#   'paper_data': [{'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32335809',
#     'pmid': '32335809',
#     'pubdate': '2020',
#     'title': 'Major Depression in Children with Transfusion-Dependent Thalassemia Is Strongly Associated with the Combined Effects of Blood Transfusion Rate, Iron Overload, and Increased Pro-inflammatory Cytokines.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, King Chulalongkorn Memorial Hospital, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Centre, Deakin University, PO Box 281, Geelong, VIC, 3220, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32217347',
#     'pmid': '32217347',
#     'pubdate': '2020',
#     'title': 'The uterine-chemokine-brain axis: menstrual cycle-associated symptoms (MCAS) are in part mediated by CCL2, CCL5, CCL11, CXCL8 and CXCL10.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria; IMPACT Strategic Research Center, Deakin University, Geelong, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32108009',
#     'pmid': '32108009',
#     'pubdate': '2020',
#     'title': 'Immunological disturbances and neuroimaging findings in Major Depressive Disorder (MDD) and Alcohol Use Disorder (AUD) comorbid patients.',
#     'affiliation': ['Faculty of Medicine, Chulalongkorn University, Bangkok. Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32034911',
#     'pmid': '32034911',
#     'pubdate': '2020',
#     'title': 'Induced ketosis as a treatment for neuroprogressive disorders: Food for thought?',
#     'affiliation': ['Department of Psychiatry and Medical Psychology, Medical Faculty, Medical University of Plovdiv, Plovdiv, Bulgaria; Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31894751',
#     'pmid': '31894751',
#     'pubdate': '2020',
#     'title': 'Plasma Indoleamine-2,3-Dioxygenase (IDO) is Increased in Drug-Naï ve Major Depressed Patients and Treatment with Sertraline and Ketoprofen Normalizes IDO in Association with Pro-Inflammatory and Immune- Regulatory Cytokines.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok 10330, Thailand.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria.',
#      'IMPACT Research Center, Deakin University, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31734845',
#     'pmid': '31734845',
#     'pubdate': '2019',
#     'title': 'Serum agrin and talin are increased in major depression while agrin and creatine phosphokinase are associated with chronic fatigue and fibromyalgia symptoms in depression.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. Dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. Dr.michaelmaes@hotmail.com.',
#      'School of Medicine, IMPACT Strategic Research Centre, Deakin University, Geelong, Australia. Dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31693974',
#     'pmid': '31693974',
#     'pubdate': '2019',
#     'title': 'Differences in the immune-inflammatory profiles of unipolar and bipolar depression.',
#     'affiliation': ['Department of Psychiatry, Chulalongkorn University, Faculty of Medicine, Bangkok, Thailand; Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Geelong, Australia; Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31545987',
#     'pmid': '31545987',
#     'pubdate': '2019',
#     'title': 'Shared pathways for neuroprogression and somatoprogression in neuropsychiatric disorders.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, Barwon Health, School of Medicine, Geelong, Victoria, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31473906',
#     'pmid': '31473906',
#     'pubdate': '2019',
#     'title': 'The Role of Aberrations in the Immune-Inflammatory Response System (IRS) and the Compensatory Immune-Regulatory Reflex System (CIRS) in Different Phenotypes of Schizophrenia: the IRS-CIRS Theory of Schizophrenia.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Centre, Deakin University, Geelong, Vic, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31470635',
#     'pmid': '31470635',
#     'pubdate': '2019',
#     'title': 'Machine Learning to Understand the Immune-Inflammatory Pathways in Fibromyalgia.',
#     'affiliation': ['Department of Psychiatry, Chulalongkorn University, Bangkok 10330, Thailand. Michael.Ma@chula.ac.th.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31323278',
#     'pmid': '31323278',
#     'pubdate': '2019',
#     'title': 'Upregulation of the nitrosylome in bipolar disorder type 1 (BP1) and major depression, but not BP2: Increased IgM antibodies to nitrosylated conjugates are associated with indicants of leaky gut.',
#     'affiliation': ['Department of Psychiatry and Medical Psychology, Medical Faculty, Medical University of Plovdiv, Plovdiv, Bulgaria; Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Impact Research Center, Deakin University, Geelong, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31292851',
#     'pmid': '31292851',
#     'pubdate': '2019',
#     'title': 'Total and ionized calcium and magnesium are significantly lowered in drug-naïve depressed patients: effects of antidepressants and associations with immune activation.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'School of Medicine, IMPACT Strategic Research Centre, Deakin University, PO Box 281, Geelong, VIC, 3220, Australia. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Center, Barwon Health, Deakin University, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31136774',
#     'pmid': '31136774',
#     'pubdate': '2019',
#     'title': 'Shared microglial mechanisms underpinning depression and chronic fatigue syndrome and their comorbidities.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; IMPACT Strategic Research Center, Deakin University, Geelong, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31124079',
#     'pmid': '31124079',
#     'pubdate': '2019',
#     'title': 'Development of a Novel Neuro-immune and Opioid-Associated Fingerprint with a Cross-Validated Ability to Identify and Authenticate Unknown Patients with Major Depression: Far Beyond Differentiation, Discrimination, and Classification.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Center, Barwon Health, Deakin University, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31062629',
#     'pmid': '31062629',
#     'pubdate': '2019',
#     'title': 'Lowered zinc and copper levels in drug-naïve patients with major depression: Effects of antidepressants, ketoprofen and immune activation.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria.',
#      'School of Medicine, IMPACT Strategic Research Centre, Deakin University, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30849414',
#     'pmid': '30849414',
#     'pubdate': '2019',
#     'title': 'Novel insights into the mechanisms underlying depression-associated experimental autoimmune encephalomyelitis.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30677547',
#     'pmid': '30677547',
#     'pubdate': '2019',
#     'title': 'IL-10 is associated with increased mu-opioid receptor levels in major depressive disorder.',
#     'affiliation': ['Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria; Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Thailand; Impact Strategic Research Center, School of Medicine, Barwon Health, Geelong, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30592255',
#     'pmid': '30592255',
#     'pubdate': '2018',
#     'title': 'Why Should Psychiatrists and Neuroscientists Worry about Paraoxonase 1?',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Medical University of Plovdiv, Chulalongkorn University and Deakin University, Plovdiv, Bulgaria.',
#      'Impact Strategic Center, Deakin University, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30471214',
#     'pmid': '30471214',
#     'pubdate': '2018',
#     'title': 'Early Life Trauma Predicts Affective Phenomenology and the Effects are Partly Mediated by Staging Coupled with Lowered Lipid-Associated Antioxidant Defences.',
#     'affiliation': ['Health Sciences Graduate Program, Health Sciences Center, State University of Londrina, Av. Robert Koch 60; 86035-380, Londrina, PR, Brazil.',
#      'Department of Psychiatry, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria.',
#      'IMPACT Strategic Research Centre, Deakin University, Geelong, Vic, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30467771',
#     'pmid': '30467771',
#     'pubdate': '2018',
#     'title': 'Supervised machine learning to decipher the complex associations between neuro-immune biomarkers and quality of life in schizophrenia.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Pathum Wan, Bangkok, 10330, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, 4000, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Center, Barwon Health, Deakin University, PO Box 281, Geelong, Vic, 3220, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30430944',
#     'pmid': '30430944',
#     'pubdate': '2018',
#     'title': 'Recognizing the Leaky Gut as a Trans-diagnostic Target for Neuroimmune Disorders Using Clinical Chemistry and Molecular Immunology Assays.',
#     'affiliation': ['Department of Psychiatry and Medical Psychology, Medical Faculty, Medical University of Plovdiv, Plovdiv, Bulgaria.',
#      'Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30430941',
#     'pmid': '30430941',
#     'pubdate': '2018',
#     'title': 'Common Environmental Factors May Underpin the Comorbidity Between Generalized Anxiety Disorder and Mood Disorders Via Activated Nitro-oxidative Pathways.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University and King Chulalongkorn Memorial Hospital, Bangkok, Thailand.',
#      'Department of Psychiatry, Faculty of Medicine, Medical University of Plovdiv, Plovdiv, Bulgaria.',
#      'Impact Strategic Center, Deakin University, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30033878',
#     'pmid': '30033878',
#     'pubdate': '2018',
#     'title': 'Serum Interleukin Levels and Insulin Resistance in Major Depressive Disorder.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. School of Medicine, IMPACT Strategic Research Centre, Deakin University, PO Box 281, Geelong, VIC, 3220, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29790237',
#     'pmid': '29790237',
#     'pubdate': '2018',
#     'title': 'Towards a new classification of stable phase schizophrenia into major and simple neuro-cognitive psychosis: Results of unsupervised machine learning analysis.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria.',
#      'IMPACT Strategic Research Center, Deakin University, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29736827',
#     'pmid': '29736827',
#     'pubdate': '2018',
#     'title': 'Generalized Anxiety Disorder (GAD) and Comorbid Major Depression with GAD Are Characterized by Enhanced Nitro-oxidative Stress, Increased Lipid Peroxidation, and Lowered Lipid-Associated Antioxidant Defenses.',
#     'affiliation': ['Health Sciences Graduation Program, Health Sciences Center, State University of Londrina, Londrina, Parana, Brazil. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv and Technological Center for Emergency Medicine, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'School of Medicine, IMPACT Strategic Research Centre, Deakin University, PO Box 281, Geelong, VIC, 3220, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29681025',
#     'pmid': '29681025',
#     'pubdate': '2018',
#     'title': 'Major Differences in Neurooxidative and Neuronitrosative Stress Pathways Between Major Depressive Disorder and Types I and II Bipolar Disorder.',
#     'affiliation': ['Health Sciences Graduation Program, Health Sciences Center, State University of Londrina, Londrina, Paraná, Brazil. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Centre, School of Medicine, Deakin University, PO Box 281, Geelong 3220, Vic, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29615850',
#     'pmid': '29615850',
#     'pubdate': '2018',
#     'title': 'Interplay Between the Gut-Brain Axis, Obesity and Cognitive Function.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, VIC, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29611101',
#     'pmid': '29611101',
#     'pubdate': '2018',
#     'title': 'The Compensatory Immune-Regulatory Reflex System (CIRS) in Depression and Bipolar Disorder.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Centre, School of Medicine, Deakin University, PO Box 281, Geelong, Vic, 3220, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29543650',
#     'pmid': '29543650',
#     'pubdate': '2018',
#     'title': 'Tryptophan catabolites along the indoleamine 2,3-dioxygenase pathway as a biological link between depression and cancer.',
#     'affiliation': ['Impact Strategic Research Center, Department of Psychiatry, Deakin University, Geelong, Victoria, Australia.',
#      'Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29380275',
#     'pmid': '29380275',
#     'pubdate': '2018',
#     'title': 'In Schizophrenia, Depression, Anxiety, and Physiosomatic Symptoms Are Strongly Related to Psychotic Symptoms and Excitation, Impairments in Episodic Memory, and Increased Production of Neurotoxic Tryptophan Catabolites: a Multivariate and Machine Learning Study.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Center, Barwon Health, Deakin University, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29367100',
#     'pmid': '29367100',
#     'pubdate': '2018',
#     'title': 'Expression levels of interferon-ɣ and type 2 deiodinase in patients diagnosed with recurrent depressive disorders.',
#     'affiliation': ['Deakin University IMPACT Strategic Research Centre, Deakin University, School of Medicine, Barwon Health, Geelong, Australia; Department of Psychiatry, Chulalongkorn University, Bangkok, Thailand; Health Sciences Graduate Program, Health Sciences Center, State University of Londrina, Brazil.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29327213',
#     'pmid': '29327213',
#     'pubdate': '2018',
#     'title': 'Add-on Treatment with Curcumin Has Antidepressive Effects in Thai Patients with Major Depression: Results of a Randomized Double-Blind Placebo-Controlled Study.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, 10330, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Center, Barwon Health, Deakin University, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29294244',
#     'pmid': '29294244',
#     'pubdate': '2018',
#     'title': 'Multiple Immune-Inflammatory and Oxidative and Nitrosative Stress Pathways Explain the Frequent Presence of Depression in Multiple Sclerosis.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29194848',
#     'pmid': '29194848',
#     'pubdate': '2017',
#     'title': 'Natural regulatory IgM-mediated autoimmune responses directed against malondialdehyde regulate oxidative and nitrosative pathways and coupled with IgM responses to nitroso adducts attenuate depressive and physiosomatic symptoms at the end of term pregnancy.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Graduation Program in Health Sciences, State University of Londrina, Londrina, Brazil.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria.',
#      'IMPACT Strategic Center, Barwon Health, Geelong, Australia.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29103192',
#     'pmid': '29103192',
#     'pubdate': '2017',
#     'title': 'Lipid Peroxidation and Immune Biomarkers Are Associated with Major Depression and Its Phenotypes, Including Treatment-Resistant Depression and Melancholia.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'IMPACT Strategic Research Centre, Deakin University, School of Medicine and Barwon Health, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.',
#      'Health Sciences Postgraduate Program, State University of Londrina, Londrina, Paraná, Brazil. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'Revitalis, Waalre, the Netherlands. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28941769',
#     'pmid': '28941769',
#     'pubdate': '2017',
#     'title': 'A neuro-immune, neuro-oxidative and neuro-nitrosative model of prenatal and postpartum depression.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Impact Strategic Research Center, Deakin University, Geelong, Australia; Medical University of Plovdiv, Department of Psychiatry and Medical Psychology, Technology Center for Emergency Medicine, Bulgaria. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28719808',
#     'pmid': '28719808',
#     'pubdate': '2017',
#     'title': 'Activated neuro-oxidative and neuro-nitrosative pathways at the end of term are associated with inflammation and physio-somatic and depression symptoms, while predicting outcome characteristics in mother and baby.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Graduation Program in Health Sciences, State University of Londrina, Londrina, Brazil; Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria; Revitalis, Waalre, The Netherlands; IMPACT Research Center, Deakin University, Geelong, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28710952',
#     'pmid': '28710952',
#     'pubdate': '2017',
#     'title': 'Indices of insulin resistance and glucotoxicity are not associated with bipolar disorder or major depressive disorder, but are differently associated with inflammatory, oxidative and nitrosative biomarkers.',
#     'affiliation': ['Department of Psychiatry, Chulalongkorn University, Bangkok, Thailand; Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Australia. Electronic address: dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28690204',
#     'pmid': '28690204',
#     'pubdate': '2017',
#     'title': 'Depressive, anxiety and hypomanic symptoms in schizophrenia may be driven by tryptophan catabolite (TRYCAT) patterning of IgA and IgM responses directed to TRYCATs.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Department of Psychiatry, Medical University of Plovdiv, Plovdiv, Bulgaria; Department of Psychiatry, Faculty of Medicine, State University of Londrina, Londrina, Brazil; Revitalis, Waalre, The Netherlands; IMPACT Strategic Research Center, Deakin University, Geelong, Australia. Electronic address: dr.michaelmaes@chula.md.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28612257',
#     'pmid': '28612257',
#     'pubdate': '2017',
#     'title': 'Peripheral Alterations in Cytokine and Chemokine Levels After Antidepressant Drug Treatment for Major Depressive Disorder: Systematic Review and Meta-Analysis.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, Australia.',
#      'Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.',
#      'Department of Psychiatry, Faculty of Medicine, State University of Londrina, Londrina, PR, Brazil.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria.',
#      'Revitalis, Waalre, The Netherlands.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28600633',
#     'pmid': '28600633',
#     'pubdate': '2017',
#     'title': 'IgM-mediated autoimmune responses to oxidative specific epitopes, but not nitrosylated adducts, are significantly decreased in pregnancy: association with bacterial translocation, perinatal and lifetime major depression and the tryptophan catabolite (TRYCAT) pathway.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Faculty of Medicine, State University of Londrina, Londrina, Brazil. dr.michaelmaes@hotmail.com.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria. dr.michaelmaes@hotmail.com.',
#      'Revitalis, Waalre, The Netherlands. dr.michaelmaes@hotmail.com.',
#      'IMPACT Research Center, Barwon Health, Deakin University, Geelong, VIC, Australia. dr.michaelmaes@hotmail.com.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28595944',
#     'pmid': '28595944',
#     'pubdate': '2017',
#     'title': 'IDO chronic immune activation and tryptophan metabolic pathway: A potential pathophysiological link between depression and obesity.',
#     'affiliation': ['Impact Strategic Research Center, Deakin University, Geelong, Australia; Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand; Health Sciences Graduate Program, Health Sciences Center, State University of Londrina, Londrina, Brazil.']},
#    {'author': 'Maes, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28578592',
#     'pmid': '28578592',
#     'pubdate': '2017',
#     'title': 'Adjunctive minocycline treatment for major depressive disorder: A proof of concept trial.',
#     'affiliation': ['4 Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']}]},
#  'Berk, Michael': {'author': 'Berk, Michael',
#   'total_count': 137,
#   'locations': "['Australia', 'Geelong', 'Melbourne']",
#   'paper_data': [{'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32296347',
#     'pmid': '32296347',
#     'pubdate': '2020',
#     'title': 'Studies on Haloperidol and Adjunctive α-Mangostin or Raw  Garcinia mangostana  Linn Pericarp on Bio-Behavioral Markers in an Immune-Inflammatory Model of Schizophrenia in Male Rats.',
#     'affiliation': ['Deakin University, IMPACT - The Institute for Mental and Physical Health and Clinical Translation, School of Medicine, Barwon Health, Geelong, Australia.',
#      'Florey Institute of Neuroscience and Mental Health, The University of Melbourne, Parkville, VIC, Australia.',
#      'Orygen, Department of Psychiatry, The Centre of Excellence in Youth Mental Health, The University of Melbourne, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32247527',
#     'pmid': '32247527',
#     'pubdate': '2020',
#     'title': 'Depression Heterogeneity and Its Biological Underpinnings: Toward Immunometabolic Depression.',
#     'affiliation': ['Institute for Mental and Physical Health and Clinical Treatment, School of Medicine, Deakin University and Barwon Health, Geelong, Victoria, Australia; Orygen, The National Centre of Excellence in Youth Mental Health, Department of Psychiatry, University of Melbourne, Melbourne, Victoria, Australia; Florey Institute of Neuroscience and Mental Health, University of Melbourne, Melbourne, Victoria, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32191534',
#     'pmid': '32191534',
#     'pubdate': '2020',
#     'title': 'What is the potential of statins in the treatment of depression?',
#     'affiliation': ['School of Medicine, Barwon Health, IMPACT - the Institute for Mental and Physical Health and Clinical Translation, Deakin University, Geelong, Australia.',
#      'Orygen, the National Centre of Excellence in Youth Mental Health, Centre for Youth Mental Health, Florey Institute for Neuroscience and Mental Health and the Department of Psychiatry, The University of Melbourne, Melbourne, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32034911',
#     'pmid': '32034911',
#     'pubdate': '2020',
#     'title': 'Induced ketosis as a treatment for neuroprogressive disorders: Food for thought?',
#     'affiliation': ['The Institute for Mental and Physical Health and Clinical Translation, School of Medicine, Deakin University, Australia.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health, the Department of Psychiatry, and the Florey Institute for Neuroscience and Mental Health, University of Melbourne, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/32001138',
#     'pmid': '32001138',
#     'pubdate': '2020',
#     'title': 'The effect of combined treatment with SSRIs and renin-angiotensin system (RAS) drugs: A propensity score matched cohort study.',
#     'affiliation': ['Deakin University, School of Medicine, IMPACT, the Institute for Mental and Physical Health and Clinical Translation, Geelong, Victoria, Australia; Orygen Youth Health Research Centre and the Centre of Youth Mental Health, The Florey Institute for Neuroscience and Mental Health and the Department of Psychiatry, University of Melbourne, Parkville, Victoria, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31948461',
#     'pmid': '31948461',
#     'pubdate': '2020',
#     'title': 'Youth Depression Alleviation with Anti-inflammatory Agents (YoDA-A): a randomised clinical trial of rosuvastatin and aspirin.',
#     'affiliation': ['Orygen, the National Centre of Excellence in Youth Mental Health, Melbourne, Australia. michael.berk@deakin.edu.au.',
#      'Centre for Youth Mental Health, University of Melbourne, Parkville, Australia. michael.berk@deakin.edu.au.',
#      'The Institute for Mental and Physical Health and Clinical Translation, Deakin University, Geelong, Australia. michael.berk@deakin.edu.au.',
#      'Florey Institute for Neuroscience and Mental Health, University of Melbourne, Parkville, Australia. michael.berk@deakin.edu.au.',
#      'Department of Psychiatry, University of Melbourne, Parkville, Australia. michael.berk@deakin.edu.au.',
#      'Barwon Health, PO Box 281, Geelong, Victoria, 3220, Australia. michael.berk@deakin.edu.au.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31693974',
#     'pmid': '31693974',
#     'pubdate': '2019',
#     'title': 'Differences in the immune-inflammatory profiles of unipolar and bipolar depression.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Geelong, Australia; Orygen, The National Centre of Excellence in Youth Mental Health, Centre for Youth Mental Health, Florey Institute for Neuroscience and Mental Health and the Department of Psychiatry, The University of Melbourne, Melbourne, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31551825',
#     'pmid': '31551825',
#     'pubdate': '2019',
#     'title': 'Neurobiology and Therapeutic Potential of Cyclooxygenase-2 (COX-2) Inhibitors for Inflammation in Neuropsychiatric Disorders.',
#     'affiliation': ['IMPACT Strategic Research Centre, Deakin University, Geelong, VIC, Australia.',
#      'University Hospital Geelong, Barwon Health, Geelong, VIC, Australia.',
#      'Department of Psychiatry, The University of Melbourne, Parkville, VIC, Australia.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health, Parkville, VIC, Australia.',
#      'Department of Psychiatry, Florey Institute of Neuroscience and Mental Health, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31545987',
#     'pmid': '31545987',
#     'pubdate': '2019',
#     'title': 'Shared pathways for neuroprogression and somatoprogression in neuropsychiatric disorders.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, Barwon Health, School of Medicine, Geelong, Victoria, Australia; Deakin University, CMMR Strategic Research Centre, School of Medicine, Geelong, Victoria, Australia; Orygen, The National Centre of Excellence in Youth Mental Health, the Department of Psychiatry and the Florey Institute for Neuroscience and Mental Health, University of Melbourne, Parkville, Victoria, Australia. Electronic address: michael.berk@barwonhealth.org.au.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31135916',
#     'pmid': '31135916',
#     'pubdate': '2019',
#     'title': 'Effect of saffron supplementation on symptoms of depression and anxiety: a systematic review and meta-analysis.',
#     'affiliation': ['IMPACT SRC, School of Medicine, Barwon Health, Deakin University, Geelong, Australia.',
#      'Department of Psychiatry, University of Melbourne, Melbourne, Australia, and Orygen, the National Centre of Excellence in Youth Mental Health, Centre for Youth Mental Health and the Florey Institute for Neuroscience and Mental Health, University of Melbourne, Melbourne, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30905130',
#     'pmid': '30905130',
#     'pubdate': '2019',
#     'title': 'Protocol and Rationale: A 24-week Double-blind, Randomized, Placebo Controlled Trial of the Efficacy of Adjunctive  Garcinia mangostana Linn. (Mangosteen) Pericarp for Schizophrenia.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Barwon Health.',
#      'Department of Psychiatry, University of Melbourne, Royal Melbourne Hospital.',
#      'Florey Institute of Neuroscience and Mental Health, University of Melbourne.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30890971',
#     'pmid': '30890971',
#     'pubdate': '2019',
#     'title': 'Statins and Inflammation: New Therapeutic Opportunities in Psychiatry.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, VIC, Australia.',
#      'Department of Psychiatry, University of Melbourne, Parkville, VIC, Australia.',
#      'The Florey Institute for Neuroscience and Mental Health, University of Melbourne, Parkville, VIC, Australia.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30690898',
#     'pmid': '30690898',
#     'pubdate': '2019',
#     'title': 'Putative neuroprotective pharmacotherapies to target the staged progression of mental illness.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, Victoria, Australia.',
#      'Mental Health, Drugs and Alcohol Services, University Hospital Geelong, Barwon Health, Geelong, Victoria, Australia.',
#      'Department of Psychiatry, The University of Melbourne, Parkville, Victoria, Australia.',
#      'Mood Disorders Research Program, Orygen, the National Centre of Excellence in Youth Mental Health, Parkville, Victoria, Australia.',
#      'Department of Psychiatry, Florey Institute of Neuroscience and Mental Health, Parkville, Victoria, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30415609',
#     'pmid': '30415609',
#     'pubdate': '2018',
#     'title': 'Fermented foods, the gut and mental health: a mechanistic overview with implications for depression and anxiety.',
#     'affiliation': ['a IMPACT Strategic Research Centre, School of Medicine , Deakin University , Geelong , Australia.',
#      'g The Department of Psychiatry and the Florey Institute of Neuroscience and Mental Health Department , The Centre of Excellence in Youth Mental Health, The University of Melbourne , Orygen , Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30328970',
#     'pmid': '30328970',
#     'pubdate': '2018',
#     'title': 'Efficacy of adjunctive Garcinia mangostana Linn (mangosteen) pericarp for bipolar depression: study protocol for a proof-of-concept trial.',
#     'affiliation': ['Deakin University, Innovation in Mental and Physical Health and Clinical Treatment (IMPACT) Strategic Research Centre, School of Medicine, Barwon Health, Geelong, Australia.',
#      'Florey Institute for Neuroscience and Mental Health, University of Melbourne, Parkville, Australia.',
#      'Department of Psychiatry, Royal Melbourne Hospital, University of Melbourne, Parkville, Australia.',
#      'Orygen, National Centre of Excellence in Youth Mental Health, Parkville, Australia.',
#      'Centre of Youth Mental Health, University of Melbourne, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30231628',
#     'pmid': '30231628',
#     'pubdate': '2018',
#     'title': 'Leaky brain in neurological and psychiatric disorders: Drivers and consequences.',
#     'affiliation': ['1 IMPACT Strategic Research Centre, Deakin University School of Medicine, and Barwon Health, Geelong, VIC, Australia.',
#      '4 Orygen, The National Centre of Excellence in Youth Mental Health, The Department of Psychiatry and The Florey Institute of Neuroscience and Mental Health, The University of Melbourne, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30145509',
#     'pmid': '30145509',
#     'pubdate': '2018',
#     'title': 'A review of the neurobiological underpinning of comorbid substance use and mood disorders.',
#     'affiliation': ['IMPACT Strategic Research Centre, Deakin University, Geelong, VIC, Australia; University Hospital Geelong, Barwon Health, Geelong VIC, Australia; Department of Psychiatry, The University of Melbourne, Parkville, VIC, Australia; Orygen, The National Centre for Excellence in Youth Mental Health, Parkville, VIC, Australia; Florey Institute of Neuroscience and Mental Health, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30008280',
#     'pmid': '30008280',
#     'pubdate': '2018',
#     'title': 'Mediator effects of parameters of inflammation and neurogenesis from a N-acetyl cysteine clinical-trial for bipolar depression.',
#     'affiliation': ['4Deakin University,School of Medicine,IMPACT Strategic Research Centre,Barwon Health,Geelong,Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29656032',
#     'pmid': '29656032',
#     'pubdate': '2018',
#     'title': 'Bioenergetics and synaptic plasticity as potential targets for individualizing treatment for depression.',
#     'affiliation': ['Deakin University, IMPACT SRC, School of Medicine, Barwon Health, Little Malop Street, Geelong, VIC 3220, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29619634',
#     'pmid': '29619634',
#     'pubdate': '2018',
#     'title': 'Add-on treatment with N-acetylcysteine for bipolar depression: a 24-week randomized double-blind parallel group placebo-controlled multicentre trial (NACOS-study protocol).',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Deakin University, Geelong, Australia.',
#      'Florey Institute for Neuroscience and Mental Health, University of Melbourne, Parkville, Australia.',
#      'Department of Psychiatry, University of Melbourne, Royal Melbourne Hospital, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29294244',
#     'pmid': '29294244',
#     'pubdate': '2018',
#     'title': 'Multiple Immune-Inflammatory and Oxidative and Nitrosative Stress Pathways Explain the Frequent Presence of Depression in Multiple Sclerosis.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Barwon Health, Geelong, Australia.',
#      'Department of Psychiatry, Medical University Plovdiv, Plovdiv, Bulgaria.',
#      'Department of Psychiatry, Faculty of Medicine, State University of Londrina, Londrina, Brazil.',
#      'Revitalis, Waalre, The Netherlands.',
#      'Orygen - The National Centre of Excellence in Youth Mental Health, The Department of Psychiatry and the Florey Institute for Neuroscience and Mental Health, The University of Melbourne, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29173706',
#     'pmid': '29173706',
#     'pubdate': '2017',
#     'title': 'Stress, Depression, and Inflammation: Molecular and Microglial Mechanisms.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Geelong, Australia; Orygen, The Centre of Excellence in Youth Mental Health, the Department of Psychiatry and the Florey Institute of Neuroscience and Mental Health, The University of Melbourne, Melbourne, Victoria, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29101602',
#     'pmid': '29101602',
#     'pubdate': '2017',
#     'title': 'Garcinia mangostana Linn displays antidepressant-like and pro-cognitive effects in a genetic animal model of depression: a bio-behavioral study in the Flinders Sensitive Line rat.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, P.O. Box 291, Geelong, 3220, Australia.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health, the Department of Psychiatry, and the Florey Institute of Neuroscience and Mental Health, The University of Melbourne, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28942748',
#     'pmid': '28942748',
#     'pubdate': '2017',
#     'title': 'Nutritional psychiatry: the present state of the evidence.',
#     'affiliation': ['Deakin University,Food & Mood Centre,IMPACT Strategic Research Centre,School of Medicine,Barwon Health,Geelong,Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28941769',
#     'pmid': '28941769',
#     'pubdate': '2017',
#     'title': 'A neuro-immune, neuro-oxidative and neuro-nitrosative model of prenatal and postpartum depression.',
#     'affiliation': ['Impact Strategic Research Center, Deakin University, Geelong, Australia; Orygen, the National Centre of Excellence in Youth Mental Health and Orygen Research, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28783937',
#     'pmid': '28783937',
#     'pubdate': '2017',
#     'title': 'Plasma Levels of Tumor Necrosis Factor Superfamily Molecules Are Increased in Bipolar Disorder.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, Geelong, Australia.',
#      'Orygen, The National Centre of Excellence in Youth Mental Health, Department of Psychiatry and The Florey Institute of Neuroscience and Mental Health, The University of Melbourne, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28760142',
#     'pmid': '28760142',
#     'pubdate': '2017',
#     'title': 'The renin-angiotensin system: a possible new target for depression.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, University Hospital Geelong, Barwon Health, Geelong, VIC, Australia.',
#      'Department of Psychiatry, Orygen the National Centre of Excellence for Youth Mental Health and Orygen Research Centre, and the Florey Institute for Neuroscience and Mental Health, University of Melbourne, Melbourne, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28710952',
#     'pmid': '28710952',
#     'pubdate': '2017',
#     'title': 'Indices of insulin resistance and glucotoxicity are not associated with bipolar disorder or major depressive disorder, but are differently associated with inflammatory, oxidative and nitrosative biomarkers.',
#     'affiliation': ['Deakin University, IMPACT Strategic Research Centre, School of Medicine, Barwon Health, Australia; Oygen, the National Centre of Excellence in Youth Mental Health, Parkville, Australia; Department of Psychiatry, University of Melbourne, Australia; The Florey Institute for Neuroscience and Mental Health, University of Melbourne, Australia. Electronic address: mikebe@barwonhealth.org.au.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28689006',
#     'pmid': '28689006',
#     'pubdate': '2017',
#     'title': 'Interactions between pro-inflammatory cytokines and statins on depression in patients with acute coronary syndrome.',
#     'affiliation': ['IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, Australia; Department of Psychiatry, The University of Melbourne, Parkville, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28578592',
#     'pmid': '28578592',
#     'pubdate': '2017',
#     'title': 'Adjunctive minocycline treatment for major depressive disorder: A proof of concept trial.',
#     'affiliation': ['1 IMPACT Strategic Research Centre, School of Medicine, Deakin University, Geelong, VIC, Australia.',
#      '2 The Florey Institute for Neuroscience and Mental Health, The University of Melbourne, Parkville, VIC, Australia.',
#      '3 Department of Psychiatry, Royal Melbourne Hospital, The University of Melbourne, Parkville, VIC, Australia.',
#      '9 Orygen Youth Health Research Centre, Parkville, VIC, Australia.',
#      '10 Centre for Youth Mental Health, The University of Melbourne, Parkville, VIC, Australia.']},
#    {'author': 'Berk, Michael',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28516431',
#     'pmid': '28516431',
#     'pubdate': '2017',
#     'title': 'A Comparison of Neuroimaging Abnormalities in Multiple Sclerosis, Major Depression and Chronic Fatigue Syndrome (Myalgic Encephalomyelitis): is There a Common Cause?',
#     'affiliation': ['The Centre for Molecular and Medical Research, School of Medicine, Deakin University, P.O. Box 291, Geelong, 3220, Australia.',
# ...
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29433074',
#     'pmid': '29433074',
#     'pubdate': '2018',
#     'title': 'The relationship between inflammatory state and quantity of affective episodes in bipolar disorder.',
#     'affiliation': ['Mood Disorders Psychopharmacology Unit (MDPU), University Health Network, University of Toronto, Toronto, Canada.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29102836',
#     'pmid': '29102836',
#     'pubdate': '2017',
#     'title': 'Efficacy and tolerability of minocycline for depression: A systematic review and meta-analysis of clinical trials.',
#     'affiliation': ['Mood Disorder Psychopharmacology Unit, University Health Network, Department of Psychiatry and Pharmacology, University of Toronto, Toronto, Ontario, Canada. Electronic address: roger.mcintyre@uhn.ca.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29084144',
#     'pmid': '29084144',
#     'pubdate': '2017',
#     'title': 'Bipolar Disorder and Immune Dysfunction: Epidemiological Findings, Proposed Pathophysiology and Clinical Implications.',
#     'affiliation': ['Department of Psychiatry, University of Toronto, Toronto, ON M5T 2S8, Canada. Roger.McIntyre@uhn.ca.',
#      'Mood Disorders Psychopharmacology Unit, University Health Network, 399 Bathurst Street, MP 9-325, Toronto, ON M5T 2S8, Canada. Roger.McIntyre@uhn.ca.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29049348',
#     'pmid': '29049348',
#     'pubdate': '2017',
#     'title': 'Chronic administration of fluoxetine and pro-inflammatory cytokine change in a rat model of depression.',
#     'affiliation': ['Institute of Medical Science, University of Toronto, Toronto, Ontario, Canada.',
#      'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, Ontario, Canada.',
#      'Department of Psychiatry, University of Toronto, Toronto, Ontario, Canada.',
#      'Department of Toxicology and Pharmacology, University of Toronto, Toronto, Ontario, Canada.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28933261',
#     'pmid': '28933261',
#     'pubdate': '2017',
#     'title': 'Pharmacological Treatment of Cognitive Symptoms in Major Depressive Disorder.',
#     'affiliation': ['Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.',
#      'Institute of Medical Science, University of Toronto, Toronto, ON, Canada.',
#      'Department of Pharmacology, University of Toronto, Toronto, ON, Canada.',
#      'Department of Psychiatry, University of Toronto, Toronto, ON, Canada.',
#      'Brain and Cognition Discovery Foundation, Toronto, ON, Canada.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28645967',
#     'pmid': '28645967',
#     'pubdate': '2017',
#     'title': 'The Bipolar Illness Onset study: research protocol for the BIO cohort study.',
#     'affiliation': ['Department of Psychiatry and Pharmacology, University of Toronto, Brain and Cognition Discovery Foundation, Toronto, Ontario, Canada.']},
#    {'author': 'McIntyre, Roger S',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28599348',
#     'pmid': '28599348',
#     'pubdate': '2017',
#     'title': 'A pilot, open-label, 8-week study evaluating the efficacy, safety and tolerability of adjunctive minocycline for the treatment of bipolar I/II depression.',
#     'affiliation': ['Institute of Medical Science, University of Toronto, Toronto, ON, Canada.',
#      'Mood Disorders Psychopharmacology Unit, University Health Network, Toronto, ON, Canada.',
#      'Department of Psychiatry, University of Toronto, Toronto, ON, Canada.',
#      'Department of Toxicology and Pharmacology, University of Toronto, Toronto, ON, Canada.']}]},
#  'Kanchanatawan, Buranee': {'author': 'Kanchanatawan, Buranee',
#   'total_count': 80,
#   'locations': "['Australia', 'Geelong', 'Thailand']",
#   'paper_data': [{'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/31473906',
#     'pmid': '31473906',
#     'pubdate': '2019',
#     'title': 'The Role of Aberrations in the Immune-Inflammatory Response System (IRS) and the Compensatory Immune-Regulatory Reflex System (CIRS) in Different Phenotypes of Schizophrenia: the IRS-CIRS Theory of Schizophrenia.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/30467771',
#     'pmid': '30467771',
#     'pubdate': '2018',
#     'title': 'Supervised machine learning to decipher the complex associations between neuro-immune biomarkers and quality of life in schizophrenia.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Pathum Wan, Bangkok, 10330, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29790237',
#     'pmid': '29790237',
#     'pubdate': '2018',
#     'title': 'Towards a new classification of stable phase schizophrenia into major and simple neuro-cognitive psychosis: Results of unsupervised machine learning analysis.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29380275',
#     'pmid': '29380275',
#     'pubdate': '2018',
#     'title': 'In Schizophrenia, Depression, Anxiety, and Physiosomatic Symptoms Are Strongly Related to Psychotic Symptoms and Excitation, Impairments in Episodic Memory, and Increased Production of Neurotoxic Tryptophan Catabolites: a Multivariate and Machine Learning Study.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29327213',
#     'pmid': '29327213',
#     'pubdate': '2018',
#     'title': 'Add-on Treatment with Curcumin Has Antidepressive Effects in Thai Patients with Major Depression: Results of a Randomized Double-Blind Placebo-Controlled Study.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, 10330, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29194848',
#     'pmid': '29194848',
#     'pubdate': '2017',
#     'title': 'Natural regulatory IgM-mediated autoimmune responses directed against malondialdehyde regulate oxidative and nitrosative pathways and coupled with IgM responses to nitroso adducts attenuate depressive and physiosomatic symptoms at the end of term pregnancy.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28719808',
#     'pmid': '28719808',
#     'pubdate': '2017',
#     'title': 'Activated neuro-oxidative and neuro-nitrosative pathways at the end of term are associated with inflammation and physio-somatic and depression symptoms, while predicting outcome characteristics in mother and baby.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28690204',
#     'pmid': '28690204',
#     'pubdate': '2017',
#     'title': 'Depressive, anxiety and hypomanic symptoms in schizophrenia may be driven by tryptophan catabolite (TRYCAT) patterning of IgA and IgM responses directed to TRYCATs.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28600633',
#     'pmid': '28600633',
#     'pubdate': '2017',
#     'title': 'IgM-mediated autoimmune responses to oxidative specific epitopes, but not nitrosylated adducts, are significantly decreased in pregnancy: association with bacterial translocation, perinatal and lifetime major depression and the tryptophan catabolite (TRYCAT) pathway.',
#     'affiliation': ['Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']},
#    {'author': 'Kanchanatawan, Buranee',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28578592',
#     'pmid': '28578592',
#     'pubdate': '2017',
#     'title': 'Adjunctive minocycline treatment for major depressive disorder: A proof of concept trial.',
#     'affiliation': ['4 Department of Psychiatry, Faculty of Medicine, Chulalongkorn University, Bangkok, Thailand.']}]},
#  'Carvalho, André F': {'author': 'Carvalho, André F',
#   'total_count': 68,
#   'locations': "['Geelong', 'Australia', 'Brazil']",
#   'paper_data': [{'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29790237',
#     'pmid': '29790237',
#     'pubdate': '2018',
#     'title': 'Towards a new classification of stable phase schizophrenia into major and simple neuro-cognitive psychosis: Results of unsupervised machine learning analysis.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29736827',
#     'pmid': '29736827',
#     'pubdate': '2018',
#     'title': 'Generalized Anxiety Disorder (GAD) and Comorbid Major Depression with GAD Are Characterized by Enhanced Nitro-oxidative Stress, Increased Lipid Peroxidation, and Lowered Lipid-Associated Antioxidant Defenses.',
#     'affiliation': ['Department of Psychiatry, University of Toronto, Toronto, ON, Canada.',
#      'Centre for Addiction & Mental Health, Toronto, ON, Canada.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29681025',
#     'pmid': '29681025',
#     'pubdate': '2018',
#     'title': 'Major Differences in Neurooxidative and Neuronitrosative Stress Pathways Between Major Depressive Disorder and Types I and II Bipolar Disorder.',
#     'affiliation': ['Department of Psychiatry, University of Toronto, Toronto, ON, Canada.',
#      'Centre for Addiction & Mental Health, Toronto, ON, Canada.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29380275',
#     'pmid': '29380275',
#     'pubdate': '2018',
#     'title': 'In Schizophrenia, Depression, Anxiety, and Physiosomatic Symptoms Are Strongly Related to Psychotic Symptoms and Excitation, Impairments in Episodic Memory, and Increased Production of Neurotoxic Tryptophan Catabolites: a Multivariate and Machine Learning Study.',
#     'affiliation': ['Department of Psychiatry, University of Toronto, Toronto, ON, Canada.',
#      'Centre for Addiction and Mental Health (CAMH), Toronto, ON, Canada.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29327213',
#     'pmid': '29327213',
#     'pubdate': '2018',
#     'title': 'Add-on Treatment with Curcumin Has Antidepressive Effects in Thai Patients with Major Depression: Results of a Randomized Double-Blind Placebo-Controlled Study.',
#     'affiliation': ['Translational Psychiatry Research Group and Department of Clinical Medicine, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/29294244',
#     'pmid': '29294244',
#     'pubdate': '2018',
#     'title': 'Multiple Immune-Inflammatory and Oxidative and Nitrosative Stress Pathways Explain the Frequent Presence of Depression in Multiple Sclerosis.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28988615',
#     'pmid': '28988615',
#     'pubdate': '2017',
#     'title': 'Mechanism of synergistic action on behavior, oxidative stress and inflammation following co-treatment with ketamine and different antidepressant classes.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28941769',
#     'pmid': '28941769',
#     'pubdate': '2017',
#     'title': 'A neuro-immune, neuro-oxidative and neuro-nitrosative model of prenatal and postpartum depression.',
#     'affiliation': ['Department of Clinical Medicine, Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceara, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28782132',
#     'pmid': '28782132',
#     'pubdate': '2017',
#     'title': 'Aspirin and incident depressive symptoms: A longitudinal cohort study over 8\xa0years.',
#     'affiliation': ['Translational Psychiatry Research Group, Department of Clinical Medicine, Faculty of Medicine, Federal University of Ceara, Fortaleza, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28760142',
#     'pmid': '28760142',
#     'pubdate': '2017',
#     'title': 'The renin-angiotensin system: a possible new target for depression.',
#     'affiliation': ['Translational Psychiatry Research Group and Department of Clinical Medicine, Faculty of Medicine, Federal University of Ceará, Fortaleza, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28719808',
#     'pmid': '28719808',
#     'pubdate': '2017',
#     'title': 'Activated neuro-oxidative and neuro-nitrosative pathways at the end of term are associated with inflammation and physio-somatic and depression symptoms, while predicting outcome characteristics in mother and baby.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28690204',
#     'pmid': '28690204',
#     'pubdate': '2017',
#     'title': 'Depressive, anxiety and hypomanic symptoms in schizophrenia may be driven by tryptophan catabolite (TRYCAT) patterning of IgA and IgM responses directed to TRYCATs.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28612257',
#     'pmid': '28612257',
#     'pubdate': '2017',
#     'title': 'Peripheral Alterations in Cytokine and Chemokine Levels After Antidepressant Drug Treatment for Major Depressive Disorder: Systematic Review and Meta-Analysis.',
#     'affiliation': ['Translational Psychiatry Research Group and Department of Clinical Medicine, Faculty of Medicine, Fortaleza, CE, Brazil. andrefc7@terra.com.br.',
#      'Department of Clinical Medicine, Faculty of Medicine, Federal University of Ceará, Rua Prof. Costa Mendes, 1608, 4° andar, Fortaleza, CE, 60430-040, Brazil. andrefc7@terra.com.br.']},
#    {'author': 'Carvalho, André F',
#     'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28600633',
#     'pmid': '28600633',
#     'pubdate': '2017',
#     'title': 'IgM-mediated autoimmune responses to oxidative specific epitopes, but not nitrosylated adducts, are significantly decreased in pregnancy: association with bacterial translocation, perinatal and lifetime major depression and the tryptophan catabolite (TRYCAT) pathway.',
#     'affiliation': ['Department of Clinical Medicine and Translational Psychiatry Research Group, Faculty of Medicine, Federal University of Ceará, Fortaleza, CE, Brazil.']}]}}

# %%
affiliations_by_author
# Out:
# [{'author': 'Pariante, Carmine M',
#   'total_papers': 22,
#   'affiliations': [{'affiliation': 'London', 'count': 15},
#    {'affiliation': 'United Kingdom', 'count': 5},
#    {'affiliation': 'none', 'count': 1}]},
#  {'author': 'Penninx, Brenda W J H',
#   'total_papers': 16,
#   'affiliations': [{'affiliation': 'Amsterdam', 'count': 12},
#    {'affiliation': 'Netherlands', 'count': 3},
#    {'affiliation': 'none', 'count': 1}]},
#  {'author': 'Fuchs, Dietmar',
#   'total_papers': 22,
#   'affiliations': [{'affiliation': 'Austria', 'count': 11},
#    {'affiliation': 'Innsbruck', 'count': 11}]},
#  {'author': 'Lamers, Femke',
#   'total_papers': 11,
#   'affiliations': [{'affiliation': 'Amsterdam', 'count': 8},
#    {'affiliation': 'Netherlands', 'count': 2},
#    {'affiliation': 'none', 'count': 1}]},
#  {'author': 'Khandaker, Golam M',
#   'total_papers': 14,
#   'affiliations': [{'affiliation': 'Cambridge', 'count': 8},
#    {'affiliation': 'Peterborough', 'count': 6}]},
#  {'author': 'Milaneschi, Yuri',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Amsterdam', 'count': 8},
#    {'affiliation': 'Netherlands', 'count': 2}]},
#  {'author': 'Fond, G',
#   'total_papers': 20,
#   'affiliations': [{'affiliation': 'France', 'count': 8},
#    {'affiliation': 'Créteil', 'count': 6},
#    {'affiliation': 'Marseille', 'count': 6}]},
#  {'author': 'Lançon, C',
#   'total_papers': 20,
#   'affiliations': [{'affiliation': 'France', 'count': 8},
#    {'affiliation': 'Marseille', 'count': 8},
#    {'affiliation': 'Créteil', 'count': 4}]},
#  {'author': 'Boyer, L',
#   'total_papers': 21,
#   'affiliations': [{'affiliation': 'France', 'count': 8},
#    {'affiliation': 'Marseille', 'count': 7},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Lewis, Glyn',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'London', 'count': 8}]},
#  {'author': 'Jones, Peter B',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'Cambridge', 'count': 7},
#    {'affiliation': 'Peterborough', 'count': 5}]},
#  {'author': 'Schoevers, Robert A',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Groningen', 'count': 7},
#    {'affiliation': 'Netherlands', 'count': 3}]},
#  {'author': 'Stubbs, Brendon',
#   'total_papers': 9,
#   'affiliations': [{'affiliation': 'London', 'count': 6},
#    {'affiliation': 'Chelmsford', 'count': 2},
#    {'affiliation': 'United Kingdom', 'count': 1}]},
#  {'author': 'Su, Kuan-Pin',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'Taiwan', 'count': 7},
#    {'affiliation': 'Taichung', 'count': 7},
#    {'affiliation': 'London', 'count': 4}]},
#  {'author': 'Godin, O',
#   'total_papers': 17,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6},
#    {'affiliation': 'Paris', 'count': 5}]},
#  {'author': 'Schürhoff, F',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Berna, F',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'Strasbourg', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Aouizerate, B',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Bordeaux', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Capdevielle, D',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Montpellier', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Dubertret, C',
#   'total_papers': 19,
#   'affiliations': [{'affiliation': 'Colombes', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Dubreucq, J',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Grenoble', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Faget, C',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6},
#    {'affiliation': 'Marseille', 'count': 6}]},
#  {'author': 'Mallet, J',
#   'total_papers': 19,
#   'affiliations': [{'affiliation': 'Colombes', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Misdrahi, D',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Bordeaux', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Passerieux, C',
#   'total_papers': 27,
#   'affiliations': [{'affiliation': 'Versailles', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Rey, R',
#   'total_papers': 13,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6},
#    {'affiliation': 'Bron', 'count': 1}]},
#  {'author': 'Urbach, M',
#   'total_papers': 27,
#   'affiliations': [{'affiliation': 'Versailles', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Vidailhet, P',
#   'total_papers': 13,
#   'affiliations': [{'affiliation': 'Strasbourg', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 1}]},
#  {'author': 'Leboyer, M',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'Llorca, P M',
#   'total_papers': 18,
#   'affiliations': [{'affiliation': 'Clermont-Ferrand', 'count': 6},
#    {'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6}]},
#  {'author': 'C, F',
#   'total_papers': 15,
#   'affiliations': [{'affiliation': 'France', 'count': 6},
#    {'affiliation': 'Créteil', 'count': 6},
#    {'affiliation': 'Clermont-Ferrand', 'count': 3}]},
#  {'author': 'Morrens, Manuel',
#   'total_papers': 9,
#   'affiliations': [{'affiliation': 'Belgium', 'count': 6},
#    {'affiliation': 'Duffel', 'count': 3}]},
#  {'author': 'Müller, Norbert',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'Munich', 'count': 6},
#    {'affiliation': 'Germany', 'count': 6}]},
#  {'author': 'Puri, Basant K',
#   'total_papers': 6,
#   'affiliations': [{'affiliation': 'London', 'count': 5},
#    {'affiliation': 'Cambridge', 'count': 1}]},
#  {'author': 'Puri, Basant K',
#   'total_papers': 6,
#   'affiliations': [{'affiliation': 'London', 'count': 5},
#    {'affiliation': 'Cambridge', 'count': 1}]},
#  {'author': 'Steptoe, Andrew',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'London', 'count': 6},
#    {'affiliation': 'United Kingdom', 'count': 2}]},
#  {'author': 'Mondelli, Valeria',
#   'total_papers': 6,
#   'affiliations': [{'affiliation': 'London', 'count': 5},
#    {'affiliation': 'none', 'count': 1}]},
#  {'author': 'Anderson, George',
#   'total_papers': 7,
#   'affiliations': [{'affiliation': 'London', 'count': 5},
#    {'affiliation': 'New Haven', 'count': 1},
#    {'affiliation': 'United Kingdom', 'count': 1}]},
#  {'author': 'Zunszain, Patricia A',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'London', 'count': 4},
#    {'affiliation': 'United Kingdom', 'count': 2},
#    {'affiliation': 'none', 'count': 2}]},
#  {'author': 'Young, Allan H',
#   'total_papers': 5,
#   'affiliations': [{'affiliation': 'London', 'count': 3},
#    {'affiliation': 'none', 'count': 2}]},
#  {'author': 'de Boer, Peter',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Beerse', 'count': 5},
#    {'affiliation': 'Belgium', 'count': 5}]},
#  {'author': 'Borsini, Alessandra',
#   'total_papers': 7,
#   'affiliations': [{'affiliation': 'London', 'count': 3},
#    {'affiliation': 'United Kingdom', 'count': 2},
#    {'affiliation': 'none', 'count': 2}]},
#  {'author': 'Chereau, I',
#   'total_papers': 15,
#   'affiliations': [{'affiliation': 'Clermont-Ferrand', 'count': 5},
#    {'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Créteil', 'count': 5}]},
#  {'author': 'Coppens, Violette',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'Belgium', 'count': 5},
#    {'affiliation': 'Duffel', 'count': 3}]},
#  {'author': 'Bullmore, Edward T',
#   'total_papers': 11,
#   'affiliations': [{'affiliation': 'Stevenage', 'count': 4},
#    {'affiliation': 'Cambridge', 'count': 4},
#    {'affiliation': 'Peterborough', 'count': 2}]},
#  {'author': 'Richieri, R',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Marseille', 'count': 5},
#    {'affiliation': 'United Kingdom', 'count': 1}]},
#  {'author': 'Chang, Jane Pei-Chen',
#   'total_papers': 14,
#   'affiliations': [{'affiliation': 'Taiwan', 'count': 5},
#    {'affiliation': 'Taichung', 'count': 5},
#    {'affiliation': 'London', 'count': 4}]},
#  {'author': 'Strawbridge, Rebecca',
#   'total_papers': 5,
#   'affiliations': [{'affiliation': 'London', 'count': 3},
#    {'affiliation': 'none', 'count': 2}]},
#  {'author': 'Platzer, Martina',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Graz', 'count': 5},
#    {'affiliation': 'Austria', 'count': 4},
#    {'affiliation': 'Germany', 'count': 1}]},
#  {'author': 'Platzer, Martina',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Graz', 'count': 5},
#    {'affiliation': 'Austria', 'count': 4},
#    {'affiliation': 'Germany', 'count': 1}]},
#  {'author': 'Birner, Armin',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Graz', 'count': 5},
#    {'affiliation': 'Austria', 'count': 5}]},
#  {'author': 'Queissner, Robert',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Graz', 'count': 5},
#    {'affiliation': 'Austria', 'count': 5}]},
#  {'author': 'Dalkner, Nina',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'Graz', 'count': 5},
#    {'affiliation': 'Austria', 'count': 5}]},
#  {'author': 'Mollnes, Tom Eirik',
#   'total_papers': 13,
#   'affiliations': [{'affiliation': 'Norway', 'count': 5},
#    {'affiliation': 'Oslo', 'count': 3},
#    {'affiliation': 'Tromsø', 'count': 2}]},
#  {'author': 'Stewart, Robert',
#   'total_papers': 7,
#   'affiliations': [{'affiliation': 'London', 'count': 4},
#    {'affiliation': 'Malawi', 'count': 1},
#    {'affiliation': 'Blantyre', 'count': 1}]},
#  {'author': "D'Amato, T",
#   'total_papers': 11,
#   'affiliations': [{'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Créteil', 'count': 5},
#    {'affiliation': 'Bron', 'count': 1}]},
#  {'author': 'Schandrin, A',
#   'total_papers': 15,
#   'affiliations': [{'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Montpellier', 'count': 5},
#    {'affiliation': 'Créteil', 'count': 5}]},
#  {'author': 'Capuron, Lucile',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Bordeaux', 'count': 5}]},
#  {'author': 'Geffard, Michel',
#   'total_papers': 10,
#   'affiliations': [{'affiliation': 'France', 'count': 5},
#    {'affiliation': 'Talence', 'count': 5}]},
#  {'author': 'Frodl, Thomas',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'Germany', 'count': 4},
#    {'affiliation': 'Magdeburg', 'count': 4}]},
#  {'author': 'Timmers, Maarten',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'Beerse', 'count': 4},
#    {'affiliation': 'Belgium', 'count': 4}]},
#  {'author': 'Leignier, S',
#   'total_papers': 12,
#   'affiliations': [{'affiliation': 'France', 'count': 4},
#    {'affiliation': 'Grenoble', 'count': 4},
#    {'affiliation': 'Créteil', 'count': 4}]},
#  {'author': 'Sabbe, Bernard',
#   'total_papers': 6,
#   'affiliations': [{'affiliation': 'Belgium', 'count': 4},
#    {'affiliation': 'Duffel', 'count': 2}]},
#  {'author': 'Cunningham, Janet L',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'Sweden', 'count': 4},
#    {'affiliation': 'Uppsala', 'count': 4}]},
#  {'author': 'Faugere, M',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'France', 'count': 4},
#    {'affiliation': 'Marseille', 'count': 4}]},
#  {'author': 'Faget-Agius, C',
#   'total_papers': 8,
#   'affiliations': [{'affiliation': 'France', 'count': 4},
#    {'affiliation': 'Marseille', 'count': 4}]}]

# %% [markdown]
# ## Save results

# %%
#Save papers by author in order of total number of papers
lengths = []
for key, df in big_df_grouped:
    df = df[['author', 'pmid']].drop_duplicates()
    lengths.append({'key' : key, 'length' : df.shape[0]})

lengths = sorted(lengths, key=lambda k: k['length'], reverse=True) 

filename = query + '_TopAuthors.xlsx'
writer = pd.ExcelWriter(filename)

final_authors_df.to_excel(writer, 'LocationsByAuthor')

for entry in lengths[0:20]:
    for key, df in big_df_grouped:
        if key == entry['key']:
            loc_list = ast.literal_eval(key[1])
            locs = []
            for loc in loc_list:
                if loc != 'none':
                    locs.append(loc)
            loc_string = '-'.join(locs)
            key_string = key[0] + ' ' + str(key[2])
            trimmed_df = df[['title', 'pubdate', 'link', 'affiliation']]
            trimmed_df['affiliation'] = trimmed_df['affiliation'].apply(' -- '.join)
            trimmed_df = trimmed_df.drop_duplicates()
            trimmed_df.to_excel(writer, key_string)
        else: pass
    
writer.save()

# %% [markdown]
# ### BREAK

# %%
# from fuzzywuzzy import fuzz
# import copy
# ### If you remove this, it edits the original `paper_counts_affiliations` list
# paper_counts_affiliations_copy = copy.deepcopy(paper_counts_affiliations)

# fuzzy_threshold = 90

# out_author_affils = []
# for author_index, author_dict in enumerate(paper_counts_affiliations_copy):
#     author = paper_counts_affiliations_copy[author_index]['author']
#     main_affil = paper_counts_affiliations_copy[author_index]['affiliations'][0]
#     main_affil_count = main_affil['count']
#     out_affils = []
    
#     for other_affil in paper_counts_affiliations_copy[author_index]['affiliations'][1:]:
#         if fuzz.partial_ratio(main_affil['affiliation'].lower(), \
#                               other_affil['affiliation'].lower()) >= fuzzy_threshold:
#             main_affil_count = main_affil_count + other_affil['count']
#         else:
#             out_affils.append(other_affil)
#     main_affil['count'] = main_affil_count
#     out_affils = [main_affil] + out_affils
#     out_author_affils.append({'author' : author, 'affiliations' : out_affils})
    
# out_author_affils

# %%
#Get matching papers
author_of_interest = top_authors_df.loc[1]['author']
print('Papers Matching: ' + author_of_interest)
matching_pmids = []
for author in authors:
    if author['author_string'] == author_of_interest:
        matching_pmids.append(author['pmid'])
        
matching_papers = []
for paper in res_dicts:
    if paper['pmid'] in matching_pmids:
        matching_papers.append(paper)
        
papers_sample = pd.DataFrame(matching_papers).to_dict('records')
matching_papers_df = pd.DataFrame(matching_papers)[0:10]
matchedPapers = matching_papers_df.drop(columns=['pub_type_list', 'journal_info_list', 'author_list', 'link', 'keywords'])
top_papers

# %%
#Get matching affiliations
matching_affiliations = []
for author in result[1]:
    author_name = author['author'][2] + ', ' + author['author'][0]
    if author_name == author_of_interest:
        for affiliation in author['affiliation']:
            matching_affiliations.append(affiliation)
print('Most Common Affiliations Matching: ' + author_of_interest)
affs = Counter(matching_affiliations)
d = dict(Counter(affs).most_common(5))
pd.DataFrame.from_dict(d, orient='index').reset_index().rename(columns={'index':'Affiliation', 0:'Count'})

# %%
#Journals the author has published in
journals = []
for paper in papers_sample:
    journals.append(paper['journal_info_list'][0])
print('Most Common Journals Matching: ' + author_of_interest)
d = dict(Counter(journals).most_common(5))
pd.DataFrame.from_dict(d, orient='index').reset_index().rename(columns={'index':'Journal', 0:'Count'})

# %%
#Keywords related to the author
keywords = []
for paper in papers_sample:
    if len(paper['keywords']) > 0:
        for i in paper['keywords']:
            keywords.append(i)
print('Keywords Matching: ' + author_of_interest)
d = dict(Counter(keywords).most_common(25))
pd.DataFrame.from_dict(d, orient='index').reset_index().rename(columns={'index':'Journal', 0:'Count'})

# %%
#author_of_interest = top_authors_df.loc[0]['author']
authors_info = []
for author_of_interest in list(top_authors_df['author']):
    matching_pmids = []
    for author in authors:
        if author['author_string'] == author_of_interest:
            matching_pmids.append(author['pmid'])

    matching_papers = []
    for paper in res_dicts:
        if paper['pmid'] in matching_pmids:
            matching_papers.append(paper)

    papers_sample = pd.DataFrame(matching_papers).to_dict('records')

    #Keywords related to the author
    keywords = []
    for paper in papers_sample:
        if len(paper['keywords']) > 0:
            for i in paper['keywords']:
                keywords.append(i)
    d = dict(Counter(keywords).most_common(25))
    keywords = list(pd.DataFrame.from_dict(d, orient='index').reset_index().rename(columns={'index':'Keyword', 0:'Count'})['Keyword'])
    
    #Get matching affiliations
    matching_affiliations = []
    for author in result[1]:
        author_name = author['author'][2] + ', ' + author['author'][0]
        if author_name == author_of_interest:
            for affiliation in author['affiliation']:
                matching_affiliations.append(affiliation)
    affs = Counter(matching_affiliations)
    d = dict(Counter(affs).most_common(5))
    aff_terms = []
    for i in pd.DataFrame.from_dict(d, orient='index').reset_index().rename(columns={'index':'Affiliation', 0:'Count'})['Affiliation']:
        aff_terms = aff_terms + [d.lower().strip() for d in i.split(',')]
    aff_terms = list(set(aff_terms))
    
    authors_info.append({'author' : author_of_interest , 'keywords' : keywords, 'aff_terms' : aff_terms})

# %%
def search_author(keywords, location = []):
    accept = []
    for author in authors_info:
        for keyword in keywords:
            if keyword.lower() in [d.lower() for d in author['keywords']]:
                if location:
                    for term in author['aff_terms']:
                            if location in term:
                                if author not in accept:
                                    accept.append(author)
                else:
                     if author not in accept:
                        accept.append(author)   
    return pd.DataFrame(accept)

# %%
search_author(['CD-8', 'Depression', 'Anxiety', 'neuroimmunology'], 'boston')

# %%
pd.DataFrame(authors_info)
